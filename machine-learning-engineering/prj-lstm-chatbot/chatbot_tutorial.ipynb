# %%
# %matplotlib inline

# %% [markdown]
# Chatbot Tutorial
# ================
# **Author:** `Matthew Inkawhich <https://github.com/MatthewInkawhich>`_

# %% [markdown]
# In this tutorial, we explore a fun and interesting use-case of recurrent
# sequence-to-sequence models. We will train a simple chatbot using movie
# scripts from the `Cornell Movie-Dialogs
# Corpus <https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html>`__.
#
# Conversational models are a hot topic in artificial intelligence
# research. Chatbots can be found in a variety of settings, including
# customer service applications and online helpdesks. These bots are often
# powered by retrieval-based models, which output predefined responses to
# questions of certain forms. In a highly restricted domain like a
# company’s IT helpdesk, these models may be sufficient, however, they are
# not robust enough for more general use-cases. Teaching a machine to
# carry out a meaningful conversation with a human in multiple domains is
# a research question that is far from solved. Recently, the deep learning
# boom has allowed for powerful generative models like Google’s `Neural
# Conversational Model <https://arxiv.org/abs/1506.05869>`__, which marks
# a large step towards multi-domain generative conversational models. In
# this tutorial, we will implement this kind of model in PyTorch.
#
# .. figure:: /_static/img/chatbot/bot.png
#    :align: center
#    :alt: bot
#
# .. code:: python
#
#   > hello?
#   Bot: hello .
#   > where am I?
#   Bot: you re in a hospital .
#   > who are you?
#   Bot: i m a lawyer .
#   > how are you doing?
#   Bot: i m fine .
#   > are you my friend?
#   Bot: no .
#   > you're under arrest
#   Bot: i m trying to help you !
#   > i'm just kidding
#   Bot: i m sorry .
#   > where are you from?
#   Bot: san francisco .
#   > it's time for me to leave
#   Bot: i know .
#   > goodbye
#   Bot: goodbye .
#
# **Tutorial Highlights**
#
# -  Handle loading and preprocessing of `Cornell Movie-Dialogs
#    Corpus <https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html>`__
#    dataset
# -  Implement a sequence-to-sequence model with `Luong attention
#    mechanism(s) <https://arxiv.org/abs/1508.04025>`__
# -  Jointly train encoder and decoder models using mini-batches
# -  Implement greedy-search decoding module
# -  Interact with trained chatbot
#
# **Acknowledgements**
#
# This tutorial borrows code from the following sources:
#
# 1) Yuan-Kuei Wu’s pytorch-chatbot implementation:
#    https://github.com/ywk991112/pytorch-chatbot
#
# 2) Sean Robertson’s practical-pytorch seq2seq-translation example:
#    https://github.com/spro/practical-pytorch/tree/master/seq2seq-translation
#
# 3) FloydHub’s Cornell Movie Corpus preprocessing code:
#    https://github.com/floydhub/textutil-preprocess-cornell-movie-corpus

# %% [markdown]
# Preparations
# ------------
#
# To start, Download the data ZIP file
# `here <https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html>`__
# and put in a ``data/`` directory under the current directory.
#
# After that, let’s import some necessities.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
# Load & Preprocess Data
# ----------------------
#
# The next step is to reformat our data file and load the data into
# structures that we can work with.
#
# The `Cornell Movie-Dialogs
# Corpus <https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html>`__
# is a rich dataset of movie character dialog:
#
# -  220,579 conversational exchanges between 10,292 pairs of movie
#    characters
# -  9,035 characters from 617 movies
# -  304,713 total utterances
#
# This dataset is large and diverse, and there is a great variation of
# language formality, time periods, sentiment, etc. Our hope is that this
# diversity makes our model robust to many forms of inputs and queries.
#
# First, we’ll take a look at some lines of our datafile to see the
# original format.

# %%
corpus_name = "cornell movie-dialogs corpus"
corpus = os.path.join("data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "movie_lines.txt"))
# Out:
# b'L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!\n'
# b'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!\n'
# b'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.\n'
# b'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?\n'
# b"L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.\n"
# b'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow\n'
# b"L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.\n"
# b'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No\n'
# b'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?\n'
# b'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?\n'

# %% [markdown]
# Create formatted data file
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# For convenience, we'll create a nicely formatted data file in which each line
# contains a tab-separated *query sentence* and a *response sentence* pair.
#
# The following functions facilitate the parsing of the raw
# *movie_lines.txt* data file.
#
# -  ``loadLines`` splits each line of the file into a dictionary of
#    fields (lineID, characterID, movieID, character, text)
# -  ``loadConversations`` groups fields of lines from ``loadLines`` into
#    conversations based on *movie_conversations.txt*
# -  ``extractSentencePairs`` extracts pairs of sentences from
#    conversations

# %%
# Splits each line of the file into a dictionary of fields
def loadLines(fileName, fields):
    lines = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            lineObj = {}
            for i, field in enumerate(fields):
                lineObj[field] = values[i]
            lines[lineObj['lineID']] = lineObj
    return lines


# Groups fields of lines from `loadLines` into conversations based on *movie_conversations.txt*
def loadConversations(fileName, lines, fields):
    conversations = []
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            convObj = {}
            for i, field in enumerate(fields):
                convObj[field] = values[i]
            # Convert string to list (convObj["utteranceIDs"] == "['L598485', 'L598486', ...]")
            utterance_id_pattern = re.compile('L[0-9]+')
            lineIds = utterance_id_pattern.findall(convObj["utteranceIDs"])
            # Reassemble lines
            convObj["lines"] = []
            for lineId in lineIds:
                convObj["lines"].append(lines[lineId])
            conversations.append(convObj)
    return conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations:
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %% [markdown]
# Now we’ll call these functions and create the file. We’ll call it
# *formatted_movie_lines.txt*.

# %%
# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict, conversations list, and field ids
lines = {}
conversations = []
MOVIE_LINES_FIELDS = ["lineID", "characterID", "movieID", "character", "text"]
MOVIE_CONVERSATIONS_FIELDS = ["character1ID", "character2ID", "movieID", "utteranceIDs"]

# Load lines and process conversations
print("\nProcessing corpus...")
lines = loadLines(os.path.join(corpus, "movie_lines.txt"), MOVIE_LINES_FIELDS)
print("\nLoading conversations...")
conversations = loadConversations(os.path.join(corpus, "movie_conversations.txt"),
                                  lines, MOVIE_CONVERSATIONS_FIELDS)

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus...
#
# Loading conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b"Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.\tWell, I thought we'd start with pronunciation, if that's okay with you.\r\n"
# b"Well, I thought we'd start with pronunciation, if that's okay with you.\tNot the hacking and gagging and spitting part.  Please.\r\n"
# b"Not the hacking and gagging and spitting part.  Please.\tOkay... then how 'bout we try out some French cuisine.  Saturday?  Night?\r\n"
# b"You're asking me out.  That's so cute. What's your name again?\tForget it.\r\n"
# b"No, no, it's my fault -- we didn't have a proper introduction ---\tCameron.\r\n"
# b"Cameron.\tThe thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\r\n"
# b"The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\tSeems like she could get a date easy enough...\r\n"
# b'Why?\tUnsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\r\n'
# b"Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\tThat's a shame.\r\n"
# b'Gosh, if only we could find Kat a boyfriend...\tLet me see what I can do.\r\n'

# %% [markdown]
# Load and trim data
# ~~~~~~~~~~~~~~~~~~
#
# Our next order of business is to create a vocabulary and load
# query/response sentence pairs into memory.
#
# Note that we are dealing with sequences of **words**, which do not have
# an implicit mapping to a discrete numerical space. Thus, we must create
# one by mapping each unique word that we encounter in our dataset to an
# index value.
#
# For this we define a ``Voc`` class, which keeps a mapping from words to
# indexes, a reverse mapping of indexes to words, a count of each word and
# a total word count. The class provides methods for adding a word to the
# vocabulary (``addWord``), adding all words in a sentence
# (``addSentence``) and trimming infrequently seen words (``trim``). More
# on trimming later.

# %%
from torchtext.datasets import SQuAD2

train_dataset = SQuAD2(split='train')
train_iter = iter(train_dataset)

# %%
row = next(train_iter)
question = row[1]
answer = row[2][0]
print('Question: ', question)
print('Answer: ', answer)
# Out:
# Question:  What areas did Beyonce compete in when she was growing up?
# Answer:  singing and dancing

# %%
def extractSentencePairs(dataset):
    train_iter = iter(dataset)
    pairs = []
    row = next(train_iter, None)
    while row is not None:
        question = row[1]
        answer = row[2][0]
        pairs.append([question, answer])
        row = next(train_iter, None)
    return pairs

extractSentencePairs(train_dataset)
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(train_dataset):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Writing newly formatted file...
#
# Sample lines from file:
# b'When did Beyonce start becoming popular?\tin the late 1990s\r\n'
# b'What areas did Beyonce compete in when she was growing up?\tsinging and dancing\r\n'
# b"When did Beyonce leave Destiny's Child and become a solo singer?\t2003\r\n"
# b'In what city and state did Beyonce  grow up? \tHouston, Texas\r\n'
# b'In which decade did Beyonce become famous?\tlate 1990s\r\n'
# b"In what R&B group was she the lead singer?\tDestiny's Child\r\n"
# b'What album made her a worldwide known artist?\tDangerously in Love\r\n'
# b"Who managed the Destiny's Child group?\tMathew Knowles\r\n"
# b'When did Beyonc\xc3\xa9 rise to fame?\tlate 1990s\r\n'
# b"What role did Beyonc\xc3\xa9 have in Destiny's Child?\tlead singer\r\n"

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we can assemble our vocabulary and query/response sentence pairs.
# Before we are ready to use this data, we must perform some
# preprocessing.
#
# First, we must convert the Unicode strings to ASCII using
# ``unicodeToAscii``. Next, we should convert all letters to lowercase and
# trim all non-letter characters except for basic punctuation
# (``normalizeString``). Finally, to aid in training convergence, we will
# filter out sentences with length greater than the ``MAX_LENGTH``
# threshold (``filterPairs``).

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 130319 sentence pairs
# Trimmed to 46954 sentence pairs
# Counting words...
# Counted words: 32034
#
# pairs:
# ['when did beyonce start becoming popular ?', 'in the late s']
# ['in which decade did beyonce become famous ?', 'late s']
# ['what album made her a worldwide known artist ?', 'dangerously in love']
# ['who managed the destiny s child group ?', 'mathew knowles']
# ['when did beyonce rise to fame ?', 'late s']
# ['when did beyonce release dangerously in love ?', '']
# ['which artist did beyonce marry ?', 'jay z']
# ['what was beyonce s first acting job in ?', 'dreamgirls']
# ['who is beyonce married to ?', 'jay z']
# ['how did beyonce describe herself as a feminist ?', 'modern day feminist']

# %% [markdown]
# Another tactic that is beneficial to achieving faster convergence during
# training is trimming rarely used words out of our vocabulary. Decreasing
# the feature space will also soften the difficulty of the function that
# the model must learn to approximate. We will do this as a two-step
# process:
#
# 1) Trim words used under ``MIN_COUNT`` threshold using the ``voc.trim``
#    function.
#
# 2) Filter out pairs with trimmed words.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 11879 / 32031 = 0.3709
# Trimmed from 46954 pairs to 28123, 0.5989 of total

# %% [markdown]
# Prepare Data for Models
# -----------------------
#
# Although we have put a great deal of effort into preparing and massaging our
# data into a nice vocabulary object and list of sentence pairs, our models
# will ultimately expect numerical torch tensors as inputs. One way to
# prepare the processed data for the models can be found in the `seq2seq
# translation
# tutorial <https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html>`__.
# In that tutorial, we use a batch size of 1, meaning that all we have to
# do is convert the words in our sentence pairs to their corresponding
# indexes from the vocabulary and feed this to the models.
#
# However, if you’re interested in speeding up training and/or would like
# to leverage GPU parallelization capabilities, you will need to train
# with mini-batches.
#
# Using mini-batches also means that we must be mindful of the variation
# of sentence length in our batches. To accommodate sentences of different
# sizes in the same batch, we will make our batched input tensor of shape
# *(max_length, batch_size)*, where sentences shorter than the
# *max_length* are zero padded after an *EOS_token*.
#
# If we simply convert our English sentences to tensors by converting
# words to their indexes(\ ``indexesFromSentence``) and zero-pad, our
# tensor would have shape *(batch_size, max_length)* and indexing the
# first dimension would return a full sequence across all time-steps.
# However, we need to be able to index our batch along time, and across
# all sequences in the batch. Therefore, we transpose our input batch
# shape to *(max_length, batch_size)*, so that indexing across the first
# dimension returns a time step across all sentences in the batch. We
# handle this transpose implicitly in the ``zeroPadding`` function.
#
# .. figure:: /_static/img/chatbot/seq2seq_batches.png
#    :align: center
#    :alt: batches
#
# The ``inputVar`` function handles the process of converting sentences to
# tensor, ultimately creating a correctly shaped zero-padded tensor. It
# also returns a tensor of ``lengths`` for each of the sequences in the
# batch which will be passed to our decoder later.
#
# The ``outputVar`` function performs a similar function to ``inputVar``,
# but instead of returning a ``lengths`` tensor, it returns a binary mask
# tensor and a maximum target sentence length. The binary mask tensor has
# the same shape as the output target tensor, but every element that is a
# *PAD_token* is 0 and all others are 1.
#
# ``batch2TrainData`` simply takes a bunch of pairs and returns the input
# and target tensors using the aforementioned functions.

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[   18,    14,     3,    60,    18],
#         [   13,   937,    41,   306,  4784],
#         [ 1257,   675,  3760,  2637,    34],
#         [  488,   258,   883,   842, 11865],
#         [  487,    46,  3761,   312,     9],
#         [  169,  6622,   665,     9,     2],
#         [11512,    24,  6182,     2,     0],
#         [ 9552,   169,     9,     0,     0],
#         [    9,     9,     2,     0,     0],
#         [    2,     2,     0,     0,     0]])
# lengths: tensor([10, 10,  9,  7,  6])
# target_variable: tensor([[11512,  6623,   339,  6866,  9137],
#         [  858,     2,     2,  2275,  4669],
#         [    2,     0,     0,     2,     2]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True, False, False,  True,  True]])
# max_target_len: 3

# %% [markdown]
# Define Models
# -------------
#
# Seq2Seq Model
# ~~~~~~~~~~~~~
#
# The brains of our chatbot is a sequence-to-sequence (seq2seq) model. The
# goal of a seq2seq model is to take a variable-length sequence as an
# input, and return a variable-length sequence as an output using a
# fixed-sized model.
#
# `Sutskever et al. <https://arxiv.org/abs/1409.3215>`__ discovered that
# by using two separate recurrent neural nets together, we can accomplish
# this task. One RNN acts as an **encoder**, which encodes a variable
# length input sequence to a fixed-length context vector. In theory, this
# context vector (the final hidden layer of the RNN) will contain semantic
# information about the query sentence that is input to the bot. The
# second RNN is a **decoder**, which takes an input word and the context
# vector, and returns a guess for the next word in the sequence and a
# hidden state to use in the next iteration.
#
# .. figure:: /_static/img/chatbot/seq2seq_ts.png
#    :align: center
#    :alt: model
#
# Image source:
# https://jeddy92.github.io/JEddy92.github.io/ts_seq2seq_intro/

# %% [markdown]
# Encoder
# ~~~~~~~
#
# The encoder RNN iterates through the input sentence one token
# (e.g. word) at a time, at each time step outputting an “output” vector
# and a “hidden state” vector. The hidden state vector is then passed to
# the next time step, while the output vector is recorded. The encoder
# transforms the context it saw at each point in the sequence into a set
# of points in a high-dimensional space, which the decoder will use to
# generate a meaningful output for the given task.
#
# At the heart of our encoder is a multi-layered Gated Recurrent Unit,
# invented by `Cho et al. <https://arxiv.org/pdf/1406.1078v3.pdf>`__ in
# 2014. We will use a bidirectional variant of the GRU, meaning that there
# are essentially two independent RNNs: one that is fed the input sequence
# in normal sequential order, and one that is fed the input sequence in
# reverse order. The outputs of each network are summed at each time step.
# Using a bidirectional GRU will give us the advantage of encoding both
# past and future contexts.
#
# Bidirectional RNN:
#
# .. figure:: /_static/img/chatbot/RNN-bidirectional.png
#    :width: 70%
#    :align: center
#    :alt: rnn_bidir
#
# Image source: https://colah.github.io/posts/2015-09-NN-Types-FP/
#
# Note that an ``embedding`` layer is used to encode our word indices in
# an arbitrarily sized feature space. For our models, this layer will map
# each word to a feature space of size *hidden_size*. When trained, these
# values should encode semantic similarity between similar meaning words.
#
# Finally, if passing a padded batch of sequences to an RNN module, we
# must pack and unpack padding around the RNN pass using
# ``nn.utils.rnn.pack_padded_sequence`` and
# ``nn.utils.rnn.pad_packed_sequence`` respectively.
#
# **Computation Graph:**
#
#    1) Convert word indexes to embeddings.
#    2) Pack padded batch of sequences for RNN module.
#    3) Forward pass through GRU.
#    4) Unpack padding.
#    5) Sum bidirectional GRU outputs.
#    6) Return output and final hidden state.
#
# **Inputs:**
#
# -  ``input_seq``: batch of input sentences; shape=\ *(max_length,
#    batch_size)*
# -  ``input_lengths``: list of sentence lengths corresponding to each
#    sentence in the batch; shape=\ *(batch_size)*
# -  ``hidden``: hidden state; shape=\ *(n_layers x num_directions,
#    batch_size, hidden_size)*
#
# **Outputs:**
#
# -  ``outputs``: output features from the last hidden layer of the GRU
#    (sum of bidirectional outputs); shape=\ *(max_length, batch_size,
#    hidden_size)*
# -  ``hidden``: updated hidden state from GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Decoder
# ~~~~~~~
#
# The decoder RNN generates the response sentence in a token-by-token
# fashion. It uses the encoder’s context vectors, and internal hidden
# states to generate the next word in the sequence. It continues
# generating words until it outputs an *EOS_token*, representing the end
# of the sentence. A common problem with a vanilla seq2seq decoder is that
# if we rely solely on the context vector to encode the entire input
# sequence’s meaning, it is likely that we will have information loss.
# This is especially the case when dealing with long input sequences,
# greatly limiting the capability of our decoder.
#
# To combat this, `Bahdanau et al. <https://arxiv.org/abs/1409.0473>`__
# created an “attention mechanism” that allows the decoder to pay
# attention to certain parts of the input sequence, rather than using the
# entire fixed context at every step.
#
# At a high level, attention is calculated using the decoder’s current
# hidden state and the encoder’s outputs. The output attention weights
# have the same shape as the input sequence, allowing us to multiply them
# by the encoder outputs, giving us a weighted sum which indicates the
# parts of encoder output to pay attention to. `Sean
# Robertson’s <https://github.com/spro>`__ figure describes this very
# well:
#
# .. figure:: /_static/img/chatbot/attn2.png
#    :align: center
#    :alt: attn2
#
# `Luong et al. <https://arxiv.org/abs/1508.04025>`__ improved upon
# Bahdanau et al.’s groundwork by creating “Global attention”. The key
# difference is that with “Global attention”, we consider all of the
# encoder’s hidden states, as opposed to Bahdanau et al.’s “Local
# attention”, which only considers the encoder’s hidden state from the
# current time step. Another difference is that with “Global attention”,
# we calculate attention weights, or energies, using the hidden state of
# the decoder from the current time step only. Bahdanau et al.’s attention
# calculation requires knowledge of the decoder’s state from the previous
# time step. Also, Luong et al. provides various methods to calculate the
# attention energies between the encoder output and decoder output which
# are called “score functions”:
#
# .. figure:: /_static/img/chatbot/scores.png
#    :width: 60%
#    :align: center
#    :alt: scores
#
# where $h_t$ = current target decoder state and $\bar{h}_s$ =
# all encoder states.
#
# Overall, the Global attention mechanism can be summarized by the
# following figure. Note that we will implement the “Attention Layer” as a
# separate ``nn.Module`` called ``Attn``. The output of this module is a
# softmax normalized weights tensor of shape *(batch_size, 1,
# max_length)*.
#
# .. figure:: /_static/img/chatbot/global_attn.png
#    :align: center
#    :width: 60%
#    :alt: global_attn

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %% [markdown]
# Now that we have defined our attention submodule, we can implement the
# actual decoder model. For the decoder, we will manually feed our batch
# one time step at a time. This means that our embedded word tensor and
# GRU output will both have shape *(1, batch_size, hidden_size)*.
#
# **Computation Graph:**
#
#    1) Get embedding of current input word.
#    2) Forward through unidirectional GRU.
#    3) Calculate attention weights from the current GRU output from (2).
#    4) Multiply attention weights to encoder outputs to get new "weighted sum" context vector.
#    5) Concatenate weighted context vector and GRU output using Luong eq. 5.
#    6) Predict next word using Luong eq. 6 (without softmax).
#    7) Return output and final hidden state.
#
# **Inputs:**
#
# -  ``input_step``: one time step (one word) of input sequence batch;
#    shape=\ *(1, batch_size)*
# -  ``last_hidden``: final hidden layer of GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*
# -  ``encoder_outputs``: encoder model’s output; shape=\ *(max_length,
#    batch_size, hidden_size)*
#
# **Outputs:**
#
# -  ``output``: softmax normalized tensor giving probabilities of each
#    word being the correct next word in the decoded sequence;
#    shape=\ *(batch_size, voc.num_words)*
# -  ``hidden``: final hidden state of GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# Define Training Procedure
# -------------------------
#
# Masked loss
# ~~~~~~~~~~~
#
# Since we are dealing with batches of padded sequences, we cannot simply
# consider all elements of the tensor when calculating loss. We define
# ``maskNLLLoss`` to calculate our loss based on our decoder’s output
# tensor, the target tensor, and a binary mask tensor describing the
# padding of the target tensor. This loss function calculates the average
# negative log likelihood of the elements that correspond to a *1* in the
# mask tensor.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# Single training iteration
# ~~~~~~~~~~~~~~~~~~~~~~~~~
#
# The ``train`` function contains the algorithm for a single training
# iteration (a single batch of inputs).
#
# We will use a couple of clever tricks to aid in convergence:
#
# -  The first trick is using **teacher forcing**. This means that at some
#    probability, set by ``teacher_forcing_ratio``, we use the current
#    target word as the decoder’s next input rather than using the
#    decoder’s current guess. This technique acts as training wheels for
#    the decoder, aiding in more efficient training. However, teacher
#    forcing can lead to model instability during inference, as the
#    decoder may not have a sufficient chance to truly craft its own
#    output sequences during training. Thus, we must be mindful of how we
#    are setting the ``teacher_forcing_ratio``, and not be fooled by fast
#    convergence.
#
# -  The second trick that we implement is **gradient clipping**. This is
#    a commonly used technique for countering the “exploding gradient”
#    problem. In essence, by clipping or thresholding gradients to a
#    maximum value, we prevent the gradients from growing exponentially
#    and either overflow (NaN), or overshoot steep cliffs in the cost
#    function.
#
# .. figure:: /_static/img/chatbot/grad_clip.png
#    :align: center
#    :width: 60%
#    :alt: grad_clip
#
# Image source: Goodfellow et al. *Deep Learning*. 2016. https://www.deeplearningbook.org/
#
# **Sequence of Operations:**
#
#    1) Forward pass entire input batch through encoder.
#    2) Initialize decoder inputs as SOS_token, and hidden state as the encoder's final hidden state.
#    3) Forward input batch sequence through decoder one time step at a time.
#    4) If teacher forcing: set next decoder input as the current target; else: set next decoder input as current decoder output.
#    5) Calculate and accumulate loss.
#    6) Perform backpropagation.
#    7) Clip gradients.
#    8) Update encoder and decoder model parameters.
#
#
# .. Note ::
#
#   PyTorch’s RNN modules (``RNN``, ``LSTM``, ``GRU``) can be used like any
#   other non-recurrent layers by simply passing them the entire input
#   sequence (or batch of sequences). We use the ``GRU`` layer like this in
#   the ``encoder``. The reality is that under the hood, there is an
#   iterative process looping over each time step calculating hidden states.
#   Alternatively, you can run these modules one time-step at a time. In
#   this case, we manually loop over the sequences during the training
#   process like we must do for the ``decoder`` model. As long as you
#   maintain the correct conceptual model of these modules, implementing
#   sequential models can be very straightforward.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# Training iterations
# ~~~~~~~~~~~~~~~~~~~
#
# It is finally time to tie the full training procedure together with the
# data. The ``trainIters`` function is responsible for running
# ``n_iterations`` of training given the passed models, optimizers, data,
# etc. This function is quite self explanatory, as we have done the heavy
# lifting with the ``train`` function.
#
# One thing to note is that when we save our model, we save a tarball
# containing the encoder and decoder state_dicts (parameters), the
# optimizers’ state_dicts, the loss, the iteration, etc. Saving the model
# in this way will give us the ultimate flexibility with the checkpoint.
# After loading a checkpoint, we will be able to use the model parameters
# to run inference, or we can continue training right where we left off.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %% [markdown]
# Define Evaluation
# -----------------
#
# After training a model, we want to be able to talk to the bot ourselves.
# First, we must define how we want the model to decode the encoded input.
#
# Greedy decoding
# ~~~~~~~~~~~~~~~
#
# Greedy decoding is the decoding method that we use during training when
# we are **NOT** using teacher forcing. In other words, for each time
# step, we simply choose the word from ``decoder_output`` with the highest
# softmax value. This decoding method is optimal on a single time-step
# level.
#
# To facilitate the greedy decoding operation, we define a
# ``GreedySearchDecoder`` class. When run, an object of this class takes
# an input sequence (``input_seq``) of shape *(input_seq length, 1)*, a
# scalar input length (``input_length``) tensor, and a ``max_length`` to
# bound the response sentence length. The input sentence is evaluated
# using the following computational graph:
#
# **Computation Graph:**
#
#    1) Forward input through encoder model.
#    2) Prepare encoder's final hidden layer to be first hidden input to the decoder.
#    3) Initialize decoder's first input as SOS_token.
#    4) Initialize tensors to append decoded words to.
#    5) Iteratively decode one word token at a time:
#        a) Forward pass through decoder.
#        b) Obtain most likely word token and its softmax score.
#        c) Record token and score.
#        d) Prepare current token to be next decoder input.
#    6) Return collections of word tokens and scores.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# Evaluate my text
# ~~~~~~~~~~~~~~~~
#
# Now that we have our decoding method defined, we can write functions for
# evaluating a string input sentence. The ``evaluate`` function manages
# the low-level process of handling the input sentence. We first format
# the sentence as an input batch of word indexes with *batch_size==1*. We
# do this by converting the words of the sentence to their corresponding
# indexes, and transposing the dimensions to prepare the tensor for our
# models. We also create a ``lengths`` tensor which contains the length of
# our input sentence. In this case, ``lengths`` is scalar because we are
# only evaluating one sentence at a time (batch_size==1). Next, we obtain
# the decoded response sentence tensor using our ``GreedySearchDecoder``
# object (``searcher``). Finally, we convert the response’s indexes to
# words and return the list of decoded words.
#
# ``evaluateInput`` acts as the user interface for our chatbot. When
# called, an input text field will spawn in which we can enter our query
# sentence. After typing our input sentence and pressing *Enter*, our text
# is normalized in the same way as our training data, and is ultimately
# fed to the ``evaluate`` function to obtain a decoded output sentence. We
# loop this process, so we can keep chatting with our bot until we enter
# either “q” or “quit”.
#
# Finally, if a sentence is entered that contains a word that is not in
# the vocabulary, we handle this gracefully by printing an error message
# and prompting the user to enter another sentence.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# Run Model
# ---------
#
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from
# scratch or set a checkpoint to load from, and build and initialize the
# models. Feel free to play with different model configurations to
# optimize performance.

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# Run Training
# ~~~~~~~~~~~~
#
# Run the following block if you want to train the model.
#
# First we set training parameters, then we initialize our optimizers, and
# finally we call the ``trainIters`` function to run our training
# iterations.

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()
    
# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 9.4006
# Iteration: 2; Percent complete: 0.1%; Average loss: 9.2263
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.9228
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.5048
# Iteration: 5; Percent complete: 0.1%; Average loss: 7.8419
# Iteration: 6; Percent complete: 0.1%; Average loss: 6.9596
# Iteration: 7; Percent complete: 0.2%; Average loss: 6.1285
# Iteration: 8; Percent complete: 0.2%; Average loss: 5.9528
# Iteration: 9; Percent complete: 0.2%; Average loss: 6.4975
# Iteration: 10; Percent complete: 0.2%; Average loss: 5.9409
# Iteration: 11; Percent complete: 0.3%; Average loss: 6.5552
# Iteration: 12; Percent complete: 0.3%; Average loss: 6.2408
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.5612
# Iteration: 14; Percent complete: 0.4%; Average loss: 5.0283
# Iteration: 15; Percent complete: 0.4%; Average loss: 5.4552
# Iteration: 16; Percent complete: 0.4%; Average loss: 5.0445
# Iteration: 17; Percent complete: 0.4%; Average loss: 4.9470
# Iteration: 18; Percent complete: 0.4%; Average loss: 5.0168
# Iteration: 19; Percent complete: 0.5%; Average loss: 5.0861
# Iteration: 20; Percent complete: 0.5%; Average loss: 5.7192
# Iteration: 21; Percent complete: 0.5%; Average loss: 4.8286
# Iteration: 22; Percent complete: 0.5%; Average loss: 4.6829
# Iteration: 23; Percent complete: 0.6%; Average loss: 5.1613
# Iteration: 24; Percent complete: 0.6%; Average loss: 4.6333
# Iteration: 25; Percent complete: 0.6%; Average loss: 4.0574
# Iteration: 26; Percent complete: 0.7%; Average loss: 5.1256
# Iteration: 27; Percent complete: 0.7%; Average loss: 4.0120
# Iteration: 28; Percent complete: 0.7%; Average loss: 4.8792
# Iteration: 29; Percent complete: 0.7%; Average loss: 4.0311
# Iteration: 30; Percent complete: 0.8%; Average loss: 4.1447
# Iteration: 31; Percent complete: 0.8%; Average loss: 4.7454
# Iteration: 32; Percent complete: 0.8%; Average loss: 4.4398
# Iteration: 33; Percent complete: 0.8%; Average loss: 4.8489
# Iteration: 34; Percent complete: 0.9%; Average loss: 4.2876
# Iteration: 35; Percent complete: 0.9%; Average loss: 4.6713
# Iteration: 36; Percent complete: 0.9%; Average loss: 4.9907
# Iteration: 37; Percent complete: 0.9%; Average loss: 4.9530
# Iteration: 38; Percent complete: 0.9%; Average loss: 4.5730
# Iteration: 39; Percent complete: 1.0%; Average loss: 3.7703
# Iteration: 40; Percent complete: 1.0%; Average loss: 4.5963
# Iteration: 41; Percent complete: 1.0%; Average loss: 3.6383
# Iteration: 42; Percent complete: 1.1%; Average loss: 3.9869
# Iteration: 43; Percent complete: 1.1%; Average loss: 3.7531
# Iteration: 44; Percent complete: 1.1%; Average loss: 4.0785
# Iteration: 45; Percent complete: 1.1%; Average loss: 3.9162
# Iteration: 46; Percent complete: 1.1%; Average loss: 4.7595
# Iteration: 47; Percent complete: 1.2%; Average loss: 4.2662
# Iteration: 48; Percent complete: 1.2%; Average loss: 4.2853
# Iteration: 49; Percent complete: 1.2%; Average loss: 3.8316
# Iteration: 50; Percent complete: 1.2%; Average loss: 3.6633
# Iteration: 51; Percent complete: 1.3%; Average loss: 3.2957
# Iteration: 52; Percent complete: 1.3%; Average loss: 4.2992
# Iteration: 53; Percent complete: 1.3%; Average loss: 3.6457
# Iteration: 54; Percent complete: 1.4%; Average loss: 3.4856
# Iteration: 55; Percent complete: 1.4%; Average loss: 3.8411
# Iteration: 56; Percent complete: 1.4%; Average loss: 4.1905
# Iteration: 57; Percent complete: 1.4%; Average loss: 4.3705
# Iteration: 58; Percent complete: 1.5%; Average loss: 3.3813
# Iteration: 59; Percent complete: 1.5%; Average loss: 4.4624
# Iteration: 60; Percent complete: 1.5%; Average loss: 4.0672
# Iteration: 61; Percent complete: 1.5%; Average loss: 3.5940
# Iteration: 62; Percent complete: 1.6%; Average loss: 4.6066
# Iteration: 63; Percent complete: 1.6%; Average loss: 3.0739
# Iteration: 64; Percent complete: 1.6%; Average loss: 3.5531
# Iteration: 65; Percent complete: 1.6%; Average loss: 4.3647
# Iteration: 66; Percent complete: 1.7%; Average loss: 3.7788
# Iteration: 67; Percent complete: 1.7%; Average loss: 4.2551
# Iteration: 68; Percent complete: 1.7%; Average loss: 3.8979
# Iteration: 69; Percent complete: 1.7%; Average loss: 4.1701
# Iteration: 70; Percent complete: 1.8%; Average loss: 4.7687
# Iteration: 71; Percent complete: 1.8%; Average loss: 3.9710
# Iteration: 72; Percent complete: 1.8%; Average loss: 4.0075
# Iteration: 73; Percent complete: 1.8%; Average loss: 4.6147
# Iteration: 74; Percent complete: 1.8%; Average loss: 3.9330
# Iteration: 75; Percent complete: 1.9%; Average loss: 3.4350
# Iteration: 76; Percent complete: 1.9%; Average loss: 4.7106
# Iteration: 77; Percent complete: 1.9%; Average loss: 2.6992
# Iteration: 78; Percent complete: 1.9%; Average loss: 4.3659
# Iteration: 79; Percent complete: 2.0%; Average loss: 3.9557
# Iteration: 80; Percent complete: 2.0%; Average loss: 4.0988
# Iteration: 81; Percent complete: 2.0%; Average loss: 3.4035
# Iteration: 82; Percent complete: 2.1%; Average loss: 5.1163
# Iteration: 83; Percent complete: 2.1%; Average loss: 3.9032
# Iteration: 84; Percent complete: 2.1%; Average loss: 4.7739
# Iteration: 85; Percent complete: 2.1%; Average loss: 4.3680
# Iteration: 86; Percent complete: 2.1%; Average loss: 3.6700
# Iteration: 87; Percent complete: 2.2%; Average loss: 4.3518
# Iteration: 88; Percent complete: 2.2%; Average loss: 3.8479
# Iteration: 89; Percent complete: 2.2%; Average loss: 3.2660
# Iteration: 90; Percent complete: 2.2%; Average loss: 4.1275
# Iteration: 91; Percent complete: 2.3%; Average loss: 4.0253
# Iteration: 92; Percent complete: 2.3%; Average loss: 3.2136
# Iteration: 93; Percent complete: 2.3%; Average loss: 4.6926
# Iteration: 94; Percent complete: 2.4%; Average loss: 3.8617
# Iteration: 95; Percent complete: 2.4%; Average loss: 3.6470
# Iteration: 96; Percent complete: 2.4%; Average loss: 3.7812
# Iteration: 97; Percent complete: 2.4%; Average loss: 4.1521
# Iteration: 98; Percent complete: 2.5%; Average loss: 3.8702
# Iteration: 99; Percent complete: 2.5%; Average loss: 4.8664
# Iteration: 100; Percent complete: 2.5%; Average loss: 4.4285
# Iteration: 101; Percent complete: 2.5%; Average loss: 3.8963
# Iteration: 102; Percent complete: 2.5%; Average loss: 4.2024
# Iteration: 103; Percent complete: 2.6%; Average loss: 3.9241
# Iteration: 104; Percent complete: 2.6%; Average loss: 3.9686
# Iteration: 105; Percent complete: 2.6%; Average loss: 4.7221
# Iteration: 106; Percent complete: 2.6%; Average loss: 4.1223
# Iteration: 107; Percent complete: 2.7%; Average loss: 4.6037
# Iteration: 108; Percent complete: 2.7%; Average loss: 4.2437
# Iteration: 109; Percent complete: 2.7%; Average loss: 4.3022
# Iteration: 110; Percent complete: 2.8%; Average loss: 4.4205
# Iteration: 111; Percent complete: 2.8%; Average loss: 4.3583
# Iteration: 112; Percent complete: 2.8%; Average loss: 4.4405
# Iteration: 113; Percent complete: 2.8%; Average loss: 4.3285
# Iteration: 114; Percent complete: 2.9%; Average loss: 3.5872
# Iteration: 115; Percent complete: 2.9%; Average loss: 4.0903
# Iteration: 116; Percent complete: 2.9%; Average loss: 3.7279
# Iteration: 117; Percent complete: 2.9%; Average loss: 4.6673
# Iteration: 118; Percent complete: 2.9%; Average loss: 4.4527
# Iteration: 119; Percent complete: 3.0%; Average loss: 4.3550
# Iteration: 120; Percent complete: 3.0%; Average loss: 4.5425
# Iteration: 121; Percent complete: 3.0%; Average loss: 4.4000
# Iteration: 122; Percent complete: 3.0%; Average loss: 3.3778
# Iteration: 123; Percent complete: 3.1%; Average loss: 3.3338
# Iteration: 124; Percent complete: 3.1%; Average loss: 4.2387
# Iteration: 125; Percent complete: 3.1%; Average loss: 3.4904
# Iteration: 126; Percent complete: 3.1%; Average loss: 3.7912
# Iteration: 127; Percent complete: 3.2%; Average loss: 4.6824
# Iteration: 128; Percent complete: 3.2%; Average loss: 3.0714
# Iteration: 129; Percent complete: 3.2%; Average loss: 3.7407
# Iteration: 130; Percent complete: 3.2%; Average loss: 3.8095
# Iteration: 131; Percent complete: 3.3%; Average loss: 4.5502
# Iteration: 132; Percent complete: 3.3%; Average loss: 3.7698
# Iteration: 133; Percent complete: 3.3%; Average loss: 3.5989
# Iteration: 134; Percent complete: 3.4%; Average loss: 4.2216
# Iteration: 135; Percent complete: 3.4%; Average loss: 4.0682
# Iteration: 136; Percent complete: 3.4%; Average loss: 3.8935
# Iteration: 137; Percent complete: 3.4%; Average loss: 4.3593
# Iteration: 138; Percent complete: 3.5%; Average loss: 4.0877
# Iteration: 139; Percent complete: 3.5%; Average loss: 3.7785
# Iteration: 140; Percent complete: 3.5%; Average loss: 3.1583
# Iteration: 141; Percent complete: 3.5%; Average loss: 4.1407
# Iteration: 142; Percent complete: 3.5%; Average loss: 4.6212
# Iteration: 143; Percent complete: 3.6%; Average loss: 3.7761
# Iteration: 144; Percent complete: 3.6%; Average loss: 3.9426
# Iteration: 145; Percent complete: 3.6%; Average loss: 4.1330
# Iteration: 146; Percent complete: 3.6%; Average loss: 3.9818
# Iteration: 147; Percent complete: 3.7%; Average loss: 4.0036
# Iteration: 148; Percent complete: 3.7%; Average loss: 4.3726
# Iteration: 149; Percent complete: 3.7%; Average loss: 4.3899
# Iteration: 150; Percent complete: 3.8%; Average loss: 3.9407
# Iteration: 151; Percent complete: 3.8%; Average loss: 4.0482
# Iteration: 152; Percent complete: 3.8%; Average loss: 3.4497
# Iteration: 153; Percent complete: 3.8%; Average loss: 4.3395
# Iteration: 154; Percent complete: 3.9%; Average loss: 4.8477
# Iteration: 155; Percent complete: 3.9%; Average loss: 3.6812
# Iteration: 156; Percent complete: 3.9%; Average loss: 4.3392
# Iteration: 157; Percent complete: 3.9%; Average loss: 4.2023
# Iteration: 158; Percent complete: 4.0%; Average loss: 4.1653
# Iteration: 159; Percent complete: 4.0%; Average loss: 3.9756
# Iteration: 160; Percent complete: 4.0%; Average loss: 4.3952
# Iteration: 161; Percent complete: 4.0%; Average loss: 4.6698
# Iteration: 162; Percent complete: 4.0%; Average loss: 4.0233
# Iteration: 163; Percent complete: 4.1%; Average loss: 4.0349
# Iteration: 164; Percent complete: 4.1%; Average loss: 4.5974
# Iteration: 165; Percent complete: 4.1%; Average loss: 4.3732
# Iteration: 166; Percent complete: 4.2%; Average loss: 4.0662
# Iteration: 167; Percent complete: 4.2%; Average loss: 4.1643
# Iteration: 168; Percent complete: 4.2%; Average loss: 3.7165
# Iteration: 169; Percent complete: 4.2%; Average loss: 3.8893
# Iteration: 170; Percent complete: 4.2%; Average loss: 4.2672
# Iteration: 171; Percent complete: 4.3%; Average loss: 4.3237
# Iteration: 172; Percent complete: 4.3%; Average loss: 3.2820
# Iteration: 173; Percent complete: 4.3%; Average loss: 3.8057
# Iteration: 174; Percent complete: 4.3%; Average loss: 4.1016
# Iteration: 175; Percent complete: 4.4%; Average loss: 3.9120
# Iteration: 176; Percent complete: 4.4%; Average loss: 4.0874
# Iteration: 177; Percent complete: 4.4%; Average loss: 4.3333
# Iteration: 178; Percent complete: 4.5%; Average loss: 2.3561
# Iteration: 179; Percent complete: 4.5%; Average loss: 3.8838
# Iteration: 180; Percent complete: 4.5%; Average loss: 4.2482
# Iteration: 181; Percent complete: 4.5%; Average loss: 3.8359
# Iteration: 182; Percent complete: 4.5%; Average loss: 4.1455
# Iteration: 183; Percent complete: 4.6%; Average loss: 4.5178
# Iteration: 184; Percent complete: 4.6%; Average loss: 3.5696
# Iteration: 185; Percent complete: 4.6%; Average loss: 3.4605
# Iteration: 186; Percent complete: 4.7%; Average loss: 3.4091
# Iteration: 187; Percent complete: 4.7%; Average loss: 4.3173
# Iteration: 188; Percent complete: 4.7%; Average loss: 4.1198
# Iteration: 189; Percent complete: 4.7%; Average loss: 4.4577
# Iteration: 190; Percent complete: 4.8%; Average loss: 3.6222
# Iteration: 191; Percent complete: 4.8%; Average loss: 3.7725
# Iteration: 192; Percent complete: 4.8%; Average loss: 3.6427
# Iteration: 193; Percent complete: 4.8%; Average loss: 3.5904
# Iteration: 194; Percent complete: 4.9%; Average loss: 2.8961
# Iteration: 195; Percent complete: 4.9%; Average loss: 4.3236
# Iteration: 196; Percent complete: 4.9%; Average loss: 4.3274
# Iteration: 197; Percent complete: 4.9%; Average loss: 4.9535
# Iteration: 198; Percent complete: 5.0%; Average loss: 4.4788
# Iteration: 199; Percent complete: 5.0%; Average loss: 3.6150
# Iteration: 200; Percent complete: 5.0%; Average loss: 3.9394
# Iteration: 201; Percent complete: 5.0%; Average loss: 4.3262
# Iteration: 202; Percent complete: 5.1%; Average loss: 4.0649
# Iteration: 203; Percent complete: 5.1%; Average loss: 4.0783
# Iteration: 204; Percent complete: 5.1%; Average loss: 3.9434
# Iteration: 205; Percent complete: 5.1%; Average loss: 3.6161
# Iteration: 206; Percent complete: 5.1%; Average loss: 3.7320
# Iteration: 207; Percent complete: 5.2%; Average loss: 3.5613
# Iteration: 208; Percent complete: 5.2%; Average loss: 4.3582
# Iteration: 209; Percent complete: 5.2%; Average loss: 3.2779
# Iteration: 210; Percent complete: 5.2%; Average loss: 3.3598
# Iteration: 211; Percent complete: 5.3%; Average loss: 3.7995
# Iteration: 212; Percent complete: 5.3%; Average loss: 4.0489
# Iteration: 213; Percent complete: 5.3%; Average loss: 4.3746
# Iteration: 214; Percent complete: 5.3%; Average loss: 3.6901
# Iteration: 215; Percent complete: 5.4%; Average loss: 4.2300
# Iteration: 216; Percent complete: 5.4%; Average loss: 3.5831
# Iteration: 217; Percent complete: 5.4%; Average loss: 3.4371
# Iteration: 218; Percent complete: 5.5%; Average loss: 4.3705
# Iteration: 219; Percent complete: 5.5%; Average loss: 4.0202
# Iteration: 220; Percent complete: 5.5%; Average loss: 3.7752
# Iteration: 221; Percent complete: 5.5%; Average loss: 4.2644
# Iteration: 222; Percent complete: 5.5%; Average loss: 3.5392
# Iteration: 223; Percent complete: 5.6%; Average loss: 3.9228
# Iteration: 224; Percent complete: 5.6%; Average loss: 3.8210
# Iteration: 225; Percent complete: 5.6%; Average loss: 4.0058
# Iteration: 226; Percent complete: 5.7%; Average loss: 3.9080
# Iteration: 227; Percent complete: 5.7%; Average loss: 4.1354
# Iteration: 228; Percent complete: 5.7%; Average loss: 3.9092
# Iteration: 229; Percent complete: 5.7%; Average loss: 3.6487
# Iteration: 230; Percent complete: 5.8%; Average loss: 3.4558
# Iteration: 231; Percent complete: 5.8%; Average loss: 3.4933
# Iteration: 232; Percent complete: 5.8%; Average loss: 3.8859
# Iteration: 233; Percent complete: 5.8%; Average loss: 4.4415
# Iteration: 234; Percent complete: 5.9%; Average loss: 3.4521
# Iteration: 235; Percent complete: 5.9%; Average loss: 3.9230
# Iteration: 236; Percent complete: 5.9%; Average loss: 3.9295
# Iteration: 237; Percent complete: 5.9%; Average loss: 3.5437
# Iteration: 238; Percent complete: 5.9%; Average loss: 3.6382
# Iteration: 239; Percent complete: 6.0%; Average loss: 4.3846
# Iteration: 240; Percent complete: 6.0%; Average loss: 4.1253
# Iteration: 241; Percent complete: 6.0%; Average loss: 4.7599
# Iteration: 242; Percent complete: 6.0%; Average loss: 4.0719
# Iteration: 243; Percent complete: 6.1%; Average loss: 4.5026
# Iteration: 244; Percent complete: 6.1%; Average loss: 3.9149
# Iteration: 245; Percent complete: 6.1%; Average loss: 3.6670
# Iteration: 246; Percent complete: 6.2%; Average loss: 3.8620
# Iteration: 247; Percent complete: 6.2%; Average loss: 4.3011
# Iteration: 248; Percent complete: 6.2%; Average loss: 2.3821
# Iteration: 249; Percent complete: 6.2%; Average loss: 4.5808
# Iteration: 250; Percent complete: 6.2%; Average loss: 4.2004
# Iteration: 251; Percent complete: 6.3%; Average loss: 3.8279
# Iteration: 252; Percent complete: 6.3%; Average loss: 3.9278
# Iteration: 253; Percent complete: 6.3%; Average loss: 4.1579
# Iteration: 254; Percent complete: 6.3%; Average loss: 3.9055
# Iteration: 255; Percent complete: 6.4%; Average loss: 4.0173
# Iteration: 256; Percent complete: 6.4%; Average loss: 3.4019
# Iteration: 257; Percent complete: 6.4%; Average loss: 4.8033
# Iteration: 258; Percent complete: 6.5%; Average loss: 3.9844
# Iteration: 259; Percent complete: 6.5%; Average loss: 3.9906
# Iteration: 260; Percent complete: 6.5%; Average loss: 4.0750
# Iteration: 261; Percent complete: 6.5%; Average loss: 3.9550
# Iteration: 262; Percent complete: 6.6%; Average loss: 3.8945
# Iteration: 263; Percent complete: 6.6%; Average loss: 4.0925
# Iteration: 264; Percent complete: 6.6%; Average loss: 4.1982
# Iteration: 265; Percent complete: 6.6%; Average loss: 3.2842
# Iteration: 266; Percent complete: 6.7%; Average loss: 4.2152
# Iteration: 267; Percent complete: 6.7%; Average loss: 2.5604
# Iteration: 268; Percent complete: 6.7%; Average loss: 3.9208
# Iteration: 269; Percent complete: 6.7%; Average loss: 2.8361
# Iteration: 270; Percent complete: 6.8%; Average loss: 4.4443
# Iteration: 271; Percent complete: 6.8%; Average loss: 3.7351
# Iteration: 272; Percent complete: 6.8%; Average loss: 4.3660
# Iteration: 273; Percent complete: 6.8%; Average loss: 4.2581
# Iteration: 274; Percent complete: 6.9%; Average loss: 4.1481
# Iteration: 275; Percent complete: 6.9%; Average loss: 3.6901
# Iteration: 276; Percent complete: 6.9%; Average loss: 3.8181
# Iteration: 277; Percent complete: 6.9%; Average loss: 4.5309
# Iteration: 278; Percent complete: 7.0%; Average loss: 4.1563
# Iteration: 279; Percent complete: 7.0%; Average loss: 4.0458
# Iteration: 280; Percent complete: 7.0%; Average loss: 4.3428
# Iteration: 281; Percent complete: 7.0%; Average loss: 3.9976
# Iteration: 282; Percent complete: 7.0%; Average loss: 3.7141
# Iteration: 283; Percent complete: 7.1%; Average loss: 3.8487
# Iteration: 284; Percent complete: 7.1%; Average loss: 3.8528
# Iteration: 285; Percent complete: 7.1%; Average loss: 3.0904
# Iteration: 286; Percent complete: 7.1%; Average loss: 4.6134
# Iteration: 287; Percent complete: 7.2%; Average loss: 4.1482
# Iteration: 288; Percent complete: 7.2%; Average loss: 3.6568
# Iteration: 289; Percent complete: 7.2%; Average loss: 4.4987
# Iteration: 290; Percent complete: 7.2%; Average loss: 3.8176
# Iteration: 291; Percent complete: 7.3%; Average loss: 3.8534
# Iteration: 292; Percent complete: 7.3%; Average loss: 4.0530
# Iteration: 293; Percent complete: 7.3%; Average loss: 3.7126
# Iteration: 294; Percent complete: 7.3%; Average loss: 4.2337
# Iteration: 295; Percent complete: 7.4%; Average loss: 3.9062
# Iteration: 296; Percent complete: 7.4%; Average loss: 4.2223
# Iteration: 297; Percent complete: 7.4%; Average loss: 4.1572
# Iteration: 298; Percent complete: 7.4%; Average loss: 3.5172
# Iteration: 299; Percent complete: 7.5%; Average loss: 3.9143
# Iteration: 300; Percent complete: 7.5%; Average loss: 3.7209
# Iteration: 301; Percent complete: 7.5%; Average loss: 4.0159
# Iteration: 302; Percent complete: 7.5%; Average loss: 4.0714
# Iteration: 303; Percent complete: 7.6%; Average loss: 3.8235
# Iteration: 304; Percent complete: 7.6%; Average loss: 4.4914
# Iteration: 305; Percent complete: 7.6%; Average loss: 3.1568
# Iteration: 306; Percent complete: 7.6%; Average loss: 3.9849
# Iteration: 307; Percent complete: 7.7%; Average loss: 3.5584
# Iteration: 308; Percent complete: 7.7%; Average loss: 4.0588
# Iteration: 309; Percent complete: 7.7%; Average loss: 3.7903
# Iteration: 310; Percent complete: 7.8%; Average loss: 4.4118
# Iteration: 311; Percent complete: 7.8%; Average loss: 4.1226
# Iteration: 312; Percent complete: 7.8%; Average loss: 3.9712
# Iteration: 313; Percent complete: 7.8%; Average loss: 4.0535
# Iteration: 314; Percent complete: 7.8%; Average loss: 4.2221
# Iteration: 315; Percent complete: 7.9%; Average loss: 4.4001
# Iteration: 316; Percent complete: 7.9%; Average loss: 3.8388
# Iteration: 317; Percent complete: 7.9%; Average loss: 3.6049
# Iteration: 318; Percent complete: 8.0%; Average loss: 3.7742
# Iteration: 319; Percent complete: 8.0%; Average loss: 3.6530
# Iteration: 320; Percent complete: 8.0%; Average loss: 3.4821
# Iteration: 321; Percent complete: 8.0%; Average loss: 4.3410
# Iteration: 322; Percent complete: 8.1%; Average loss: 3.3575
# Iteration: 323; Percent complete: 8.1%; Average loss: 4.4341
# Iteration: 324; Percent complete: 8.1%; Average loss: 3.2932
# Iteration: 325; Percent complete: 8.1%; Average loss: 4.1347
# Iteration: 326; Percent complete: 8.2%; Average loss: 4.2941
# Iteration: 327; Percent complete: 8.2%; Average loss: 3.8123
# Iteration: 328; Percent complete: 8.2%; Average loss: 3.4132
# Iteration: 329; Percent complete: 8.2%; Average loss: 3.8619
# Iteration: 330; Percent complete: 8.2%; Average loss: 3.9532
# Iteration: 331; Percent complete: 8.3%; Average loss: 4.1149
# Iteration: 332; Percent complete: 8.3%; Average loss: 3.9339
# Iteration: 333; Percent complete: 8.3%; Average loss: 3.9016
# Iteration: 334; Percent complete: 8.3%; Average loss: 4.2240
# Iteration: 335; Percent complete: 8.4%; Average loss: 4.2086
# Iteration: 336; Percent complete: 8.4%; Average loss: 4.4633
# Iteration: 337; Percent complete: 8.4%; Average loss: 3.8218
# Iteration: 338; Percent complete: 8.5%; Average loss: 4.5509
# Iteration: 339; Percent complete: 8.5%; Average loss: 4.1215
# Iteration: 340; Percent complete: 8.5%; Average loss: 3.8366
# Iteration: 341; Percent complete: 8.5%; Average loss: 3.5543
# Iteration: 342; Percent complete: 8.6%; Average loss: 3.2120
# Iteration: 343; Percent complete: 8.6%; Average loss: 3.8278
# Iteration: 344; Percent complete: 8.6%; Average loss: 4.4601
# Iteration: 345; Percent complete: 8.6%; Average loss: 2.8322
# Iteration: 346; Percent complete: 8.6%; Average loss: 3.5633
# Iteration: 347; Percent complete: 8.7%; Average loss: 3.4125
# Iteration: 348; Percent complete: 8.7%; Average loss: 3.1954
# Iteration: 349; Percent complete: 8.7%; Average loss: 3.3524
# Iteration: 350; Percent complete: 8.8%; Average loss: 4.2034
# Iteration: 351; Percent complete: 8.8%; Average loss: 3.6259
# Iteration: 352; Percent complete: 8.8%; Average loss: 4.4668
# Iteration: 353; Percent complete: 8.8%; Average loss: 3.4480
# Iteration: 354; Percent complete: 8.8%; Average loss: 3.2717
# Iteration: 355; Percent complete: 8.9%; Average loss: 4.3846
# Iteration: 356; Percent complete: 8.9%; Average loss: 4.0881
# Iteration: 357; Percent complete: 8.9%; Average loss: 3.6869
# Iteration: 358; Percent complete: 8.9%; Average loss: 3.7441
# Iteration: 359; Percent complete: 9.0%; Average loss: 4.1328
# Iteration: 360; Percent complete: 9.0%; Average loss: 3.9143
# Iteration: 361; Percent complete: 9.0%; Average loss: 4.3241
# Iteration: 362; Percent complete: 9.0%; Average loss: 3.9734
# Iteration: 363; Percent complete: 9.1%; Average loss: 3.8250
# Iteration: 364; Percent complete: 9.1%; Average loss: 4.3421
# Iteration: 365; Percent complete: 9.1%; Average loss: 4.1292
# Iteration: 366; Percent complete: 9.2%; Average loss: 4.0888
# Iteration: 367; Percent complete: 9.2%; Average loss: 3.8719
# Iteration: 368; Percent complete: 9.2%; Average loss: 3.9424
# Iteration: 369; Percent complete: 9.2%; Average loss: 3.9043
# Iteration: 370; Percent complete: 9.2%; Average loss: 3.4601
# Iteration: 371; Percent complete: 9.3%; Average loss: 3.7293
# Iteration: 372; Percent complete: 9.3%; Average loss: 3.8908
# Iteration: 373; Percent complete: 9.3%; Average loss: 4.3827
# Iteration: 374; Percent complete: 9.3%; Average loss: 3.2275
# Iteration: 375; Percent complete: 9.4%; Average loss: 3.7582
# Iteration: 376; Percent complete: 9.4%; Average loss: 3.2053
# Iteration: 377; Percent complete: 9.4%; Average loss: 3.9137
# Iteration: 378; Percent complete: 9.4%; Average loss: 3.7440
# Iteration: 379; Percent complete: 9.5%; Average loss: 3.3039
# Iteration: 380; Percent complete: 9.5%; Average loss: 4.1594
# Iteration: 381; Percent complete: 9.5%; Average loss: 4.1037
# Iteration: 382; Percent complete: 9.6%; Average loss: 3.6585
# Iteration: 383; Percent complete: 9.6%; Average loss: 3.7965
# Iteration: 384; Percent complete: 9.6%; Average loss: 4.0206
# Iteration: 385; Percent complete: 9.6%; Average loss: 4.0926
# Iteration: 386; Percent complete: 9.7%; Average loss: 3.2413
# Iteration: 387; Percent complete: 9.7%; Average loss: 3.8918
# Iteration: 388; Percent complete: 9.7%; Average loss: 3.7474
# Iteration: 389; Percent complete: 9.7%; Average loss: 3.9782
# Iteration: 390; Percent complete: 9.8%; Average loss: 3.9874
# Iteration: 391; Percent complete: 9.8%; Average loss: 3.7868
# Iteration: 392; Percent complete: 9.8%; Average loss: 3.4708
# Iteration: 393; Percent complete: 9.8%; Average loss: 3.4685
# Iteration: 394; Percent complete: 9.8%; Average loss: 4.3592
# Iteration: 395; Percent complete: 9.9%; Average loss: 3.5518
# Iteration: 396; Percent complete: 9.9%; Average loss: 3.4696
# Iteration: 397; Percent complete: 9.9%; Average loss: 3.4447
# Iteration: 398; Percent complete: 10.0%; Average loss: 4.2448
# Iteration: 399; Percent complete: 10.0%; Average loss: 3.9343
# Iteration: 400; Percent complete: 10.0%; Average loss: 3.5922
# Iteration: 401; Percent complete: 10.0%; Average loss: 3.2410
# Iteration: 402; Percent complete: 10.1%; Average loss: 3.4985
# Iteration: 403; Percent complete: 10.1%; Average loss: 3.4886
# Iteration: 404; Percent complete: 10.1%; Average loss: 4.0264
# Iteration: 405; Percent complete: 10.1%; Average loss: 3.4641
# Iteration: 406; Percent complete: 10.2%; Average loss: 3.4596
# Iteration: 407; Percent complete: 10.2%; Average loss: 3.8882
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.9540
# Iteration: 409; Percent complete: 10.2%; Average loss: 4.0620
# Iteration: 410; Percent complete: 10.2%; Average loss: 3.6490
# Iteration: 411; Percent complete: 10.3%; Average loss: 3.4382
# Iteration: 412; Percent complete: 10.3%; Average loss: 3.2947
# Iteration: 413; Percent complete: 10.3%; Average loss: 3.5662
# Iteration: 414; Percent complete: 10.3%; Average loss: 3.3407
# Iteration: 415; Percent complete: 10.4%; Average loss: 4.0862
# Iteration: 416; Percent complete: 10.4%; Average loss: 3.9544
# Iteration: 417; Percent complete: 10.4%; Average loss: 3.6250
# Iteration: 418; Percent complete: 10.4%; Average loss: 3.8856
# Iteration: 419; Percent complete: 10.5%; Average loss: 2.9471
# Iteration: 420; Percent complete: 10.5%; Average loss: 2.9609
# Iteration: 421; Percent complete: 10.5%; Average loss: 3.3248
# Iteration: 422; Percent complete: 10.5%; Average loss: 4.0726
# Iteration: 423; Percent complete: 10.6%; Average loss: 3.6592
# Iteration: 424; Percent complete: 10.6%; Average loss: 3.7736
# Iteration: 425; Percent complete: 10.6%; Average loss: 3.8777
# Iteration: 426; Percent complete: 10.7%; Average loss: 3.3545
# Iteration: 427; Percent complete: 10.7%; Average loss: 3.8962
# Iteration: 428; Percent complete: 10.7%; Average loss: 3.9403
# Iteration: 429; Percent complete: 10.7%; Average loss: 4.2879
# Iteration: 430; Percent complete: 10.8%; Average loss: 3.8505
# Iteration: 431; Percent complete: 10.8%; Average loss: 4.3172
# Iteration: 432; Percent complete: 10.8%; Average loss: 4.4370
# Iteration: 433; Percent complete: 10.8%; Average loss: 3.5468
# Iteration: 434; Percent complete: 10.8%; Average loss: 3.6352
# Iteration: 435; Percent complete: 10.9%; Average loss: 4.4301
# Iteration: 436; Percent complete: 10.9%; Average loss: 3.7864
# Iteration: 437; Percent complete: 10.9%; Average loss: 3.6225
# Iteration: 438; Percent complete: 10.9%; Average loss: 3.8298
# Iteration: 439; Percent complete: 11.0%; Average loss: 2.9663
# Iteration: 440; Percent complete: 11.0%; Average loss: 3.1374
# Iteration: 441; Percent complete: 11.0%; Average loss: 2.9439
# Iteration: 442; Percent complete: 11.1%; Average loss: 4.0481
# Iteration: 443; Percent complete: 11.1%; Average loss: 3.8488
# Iteration: 444; Percent complete: 11.1%; Average loss: 3.9686
# Iteration: 445; Percent complete: 11.1%; Average loss: 3.5636
# Iteration: 446; Percent complete: 11.2%; Average loss: 3.4240
# Iteration: 447; Percent complete: 11.2%; Average loss: 3.3649
# Iteration: 448; Percent complete: 11.2%; Average loss: 3.5472
# Iteration: 449; Percent complete: 11.2%; Average loss: 3.1438
# Iteration: 450; Percent complete: 11.2%; Average loss: 3.8758
# Iteration: 451; Percent complete: 11.3%; Average loss: 3.8051
# Iteration: 452; Percent complete: 11.3%; Average loss: 3.3425
# Iteration: 453; Percent complete: 11.3%; Average loss: 3.9241
# Iteration: 454; Percent complete: 11.3%; Average loss: 3.8944
# Iteration: 455; Percent complete: 11.4%; Average loss: 3.6759
# Iteration: 456; Percent complete: 11.4%; Average loss: 3.1971
# Iteration: 457; Percent complete: 11.4%; Average loss: 3.5308
# Iteration: 458; Percent complete: 11.5%; Average loss: 3.9621
# Iteration: 459; Percent complete: 11.5%; Average loss: 4.2460
# Iteration: 460; Percent complete: 11.5%; Average loss: 3.3791
# Iteration: 461; Percent complete: 11.5%; Average loss: 3.4339
# Iteration: 462; Percent complete: 11.6%; Average loss: 3.3588
# Iteration: 463; Percent complete: 11.6%; Average loss: 3.5766
# Iteration: 464; Percent complete: 11.6%; Average loss: 4.1642
# Iteration: 465; Percent complete: 11.6%; Average loss: 4.1078
# Iteration: 466; Percent complete: 11.7%; Average loss: 3.7119
# Iteration: 467; Percent complete: 11.7%; Average loss: 3.8483
# Iteration: 468; Percent complete: 11.7%; Average loss: 4.0607
# Iteration: 469; Percent complete: 11.7%; Average loss: 4.7361
# Iteration: 470; Percent complete: 11.8%; Average loss: 3.2859
# Iteration: 471; Percent complete: 11.8%; Average loss: 3.5459
# Iteration: 472; Percent complete: 11.8%; Average loss: 3.0010
# Iteration: 473; Percent complete: 11.8%; Average loss: 3.8771
# Iteration: 474; Percent complete: 11.8%; Average loss: 3.8823
# Iteration: 475; Percent complete: 11.9%; Average loss: 4.1404
# Iteration: 476; Percent complete: 11.9%; Average loss: 3.6358
# Iteration: 477; Percent complete: 11.9%; Average loss: 2.7152
# Iteration: 478; Percent complete: 11.9%; Average loss: 4.1806
# Iteration: 479; Percent complete: 12.0%; Average loss: 2.7035
# Iteration: 480; Percent complete: 12.0%; Average loss: 2.8585
# Iteration: 481; Percent complete: 12.0%; Average loss: 3.5813
# Iteration: 482; Percent complete: 12.0%; Average loss: 2.7526
# Iteration: 483; Percent complete: 12.1%; Average loss: 3.5237
# Iteration: 484; Percent complete: 12.1%; Average loss: 4.0127
# Iteration: 485; Percent complete: 12.1%; Average loss: 4.3370
# Iteration: 486; Percent complete: 12.2%; Average loss: 3.6856
# Iteration: 487; Percent complete: 12.2%; Average loss: 3.2513
# Iteration: 488; Percent complete: 12.2%; Average loss: 3.5145
# Iteration: 489; Percent complete: 12.2%; Average loss: 4.1044
# Iteration: 490; Percent complete: 12.2%; Average loss: 3.0629
# Iteration: 491; Percent complete: 12.3%; Average loss: 3.2670
# Iteration: 492; Percent complete: 12.3%; Average loss: 3.9514
# Iteration: 493; Percent complete: 12.3%; Average loss: 3.6317
# Iteration: 494; Percent complete: 12.3%; Average loss: 3.3527
# Iteration: 495; Percent complete: 12.4%; Average loss: 3.9399
# Iteration: 496; Percent complete: 12.4%; Average loss: 3.8004
# Iteration: 497; Percent complete: 12.4%; Average loss: 4.0684
# Iteration: 498; Percent complete: 12.4%; Average loss: 4.1527
# Iteration: 499; Percent complete: 12.5%; Average loss: 3.9239
# Iteration: 500; Percent complete: 12.5%; Average loss: 3.5436
# Iteration: 501; Percent complete: 12.5%; Average loss: 3.9714
# Iteration: 502; Percent complete: 12.6%; Average loss: 3.9986
# Iteration: 503; Percent complete: 12.6%; Average loss: 3.3002
# Iteration: 504; Percent complete: 12.6%; Average loss: 3.6027
# Iteration: 505; Percent complete: 12.6%; Average loss: 3.3865
# Iteration: 506; Percent complete: 12.7%; Average loss: 3.6426
# Iteration: 507; Percent complete: 12.7%; Average loss: 3.4889
# Iteration: 508; Percent complete: 12.7%; Average loss: 3.6570
# Iteration: 509; Percent complete: 12.7%; Average loss: 4.2291
# Iteration: 510; Percent complete: 12.8%; Average loss: 3.3451
# Iteration: 511; Percent complete: 12.8%; Average loss: 3.0637
# Iteration: 512; Percent complete: 12.8%; Average loss: 3.6022
# Iteration: 513; Percent complete: 12.8%; Average loss: 3.8570
# Iteration: 514; Percent complete: 12.8%; Average loss: 3.3718
# Iteration: 515; Percent complete: 12.9%; Average loss: 3.7678
# Iteration: 516; Percent complete: 12.9%; Average loss: 3.2299
# Iteration: 517; Percent complete: 12.9%; Average loss: 3.1993
# Iteration: 518; Percent complete: 13.0%; Average loss: 3.2075
# Iteration: 519; Percent complete: 13.0%; Average loss: 3.1739
# Iteration: 520; Percent complete: 13.0%; Average loss: 3.4936
# Iteration: 521; Percent complete: 13.0%; Average loss: 2.5986
# Iteration: 522; Percent complete: 13.1%; Average loss: 3.7982
# Iteration: 523; Percent complete: 13.1%; Average loss: 3.3445
# Iteration: 524; Percent complete: 13.1%; Average loss: 4.2723
# Iteration: 525; Percent complete: 13.1%; Average loss: 3.9202
# Iteration: 526; Percent complete: 13.2%; Average loss: 3.4277
# Iteration: 527; Percent complete: 13.2%; Average loss: 3.9329
# Iteration: 528; Percent complete: 13.2%; Average loss: 3.7845
# Iteration: 529; Percent complete: 13.2%; Average loss: 4.0212
# Iteration: 530; Percent complete: 13.2%; Average loss: 3.8816
# Iteration: 531; Percent complete: 13.3%; Average loss: 4.0143
# Iteration: 532; Percent complete: 13.3%; Average loss: 4.2828
# Iteration: 533; Percent complete: 13.3%; Average loss: 4.1966
# Iteration: 534; Percent complete: 13.4%; Average loss: 3.6774
# Iteration: 535; Percent complete: 13.4%; Average loss: 4.1548
# Iteration: 536; Percent complete: 13.4%; Average loss: 2.9884
# Iteration: 537; Percent complete: 13.4%; Average loss: 2.8618
# Iteration: 538; Percent complete: 13.5%; Average loss: 3.5047
# Iteration: 539; Percent complete: 13.5%; Average loss: 4.2086
# Iteration: 540; Percent complete: 13.5%; Average loss: 4.2063
# Iteration: 541; Percent complete: 13.5%; Average loss: 3.7646
# Iteration: 542; Percent complete: 13.6%; Average loss: 3.2591
# Iteration: 543; Percent complete: 13.6%; Average loss: 3.8548
# Iteration: 544; Percent complete: 13.6%; Average loss: 3.9614
# Iteration: 545; Percent complete: 13.6%; Average loss: 4.0848
# Iteration: 546; Percent complete: 13.7%; Average loss: 4.1585
# Iteration: 547; Percent complete: 13.7%; Average loss: 3.6556
# Iteration: 548; Percent complete: 13.7%; Average loss: 3.6326
# Iteration: 549; Percent complete: 13.7%; Average loss: 3.3901
# Iteration: 550; Percent complete: 13.8%; Average loss: 4.1502
# Iteration: 551; Percent complete: 13.8%; Average loss: 4.4654
# Iteration: 552; Percent complete: 13.8%; Average loss: 4.3853
# Iteration: 553; Percent complete: 13.8%; Average loss: 4.0594
# Iteration: 554; Percent complete: 13.9%; Average loss: 4.3512
# Iteration: 555; Percent complete: 13.9%; Average loss: 3.7484
# Iteration: 556; Percent complete: 13.9%; Average loss: 3.8456
# Iteration: 557; Percent complete: 13.9%; Average loss: 4.2392
# Iteration: 558; Percent complete: 14.0%; Average loss: 3.7997
# Iteration: 559; Percent complete: 14.0%; Average loss: 3.5830
# Iteration: 560; Percent complete: 14.0%; Average loss: 3.8258
# Iteration: 561; Percent complete: 14.0%; Average loss: 3.6839
# Iteration: 562; Percent complete: 14.1%; Average loss: 3.9432
# Iteration: 563; Percent complete: 14.1%; Average loss: 3.6426
# Iteration: 564; Percent complete: 14.1%; Average loss: 3.8031
# Iteration: 565; Percent complete: 14.1%; Average loss: 4.0609
# Iteration: 566; Percent complete: 14.1%; Average loss: 3.7528
# Iteration: 567; Percent complete: 14.2%; Average loss: 3.2487
# Iteration: 568; Percent complete: 14.2%; Average loss: 3.6167
# Iteration: 569; Percent complete: 14.2%; Average loss: 3.9840
# Iteration: 570; Percent complete: 14.2%; Average loss: 3.5423
# Iteration: 571; Percent complete: 14.3%; Average loss: 4.0110
# Iteration: 572; Percent complete: 14.3%; Average loss: 4.2275
# Iteration: 573; Percent complete: 14.3%; Average loss: 3.8772
# Iteration: 574; Percent complete: 14.3%; Average loss: 3.5651
# Iteration: 575; Percent complete: 14.4%; Average loss: 3.7028
# Iteration: 576; Percent complete: 14.4%; Average loss: 3.2021
# Iteration: 577; Percent complete: 14.4%; Average loss: 3.7690
# Iteration: 578; Percent complete: 14.4%; Average loss: 2.9701
# Iteration: 579; Percent complete: 14.5%; Average loss: 3.1280
# Iteration: 580; Percent complete: 14.5%; Average loss: 3.9613
# Iteration: 581; Percent complete: 14.5%; Average loss: 3.5897
# Iteration: 582; Percent complete: 14.5%; Average loss: 4.0139
# Iteration: 583; Percent complete: 14.6%; Average loss: 3.6397
# Iteration: 584; Percent complete: 14.6%; Average loss: 3.1849
# Iteration: 585; Percent complete: 14.6%; Average loss: 2.6868
# Iteration: 586; Percent complete: 14.6%; Average loss: 3.9749
# Iteration: 587; Percent complete: 14.7%; Average loss: 3.3282
# Iteration: 588; Percent complete: 14.7%; Average loss: 3.3307
# Iteration: 589; Percent complete: 14.7%; Average loss: 3.3903
# Iteration: 590; Percent complete: 14.8%; Average loss: 3.4611
# Iteration: 591; Percent complete: 14.8%; Average loss: 3.4873
# Iteration: 592; Percent complete: 14.8%; Average loss: 3.9380
# Iteration: 593; Percent complete: 14.8%; Average loss: 3.2916
# Iteration: 594; Percent complete: 14.8%; Average loss: 3.8721
# Iteration: 595; Percent complete: 14.9%; Average loss: 3.4524
# Iteration: 596; Percent complete: 14.9%; Average loss: 3.4909
# Iteration: 597; Percent complete: 14.9%; Average loss: 3.6945
# Iteration: 598; Percent complete: 14.9%; Average loss: 3.8971
# Iteration: 599; Percent complete: 15.0%; Average loss: 3.6814
# Iteration: 600; Percent complete: 15.0%; Average loss: 4.1543
# Iteration: 601; Percent complete: 15.0%; Average loss: 3.3295
# Iteration: 602; Percent complete: 15.0%; Average loss: 3.3886
# Iteration: 603; Percent complete: 15.1%; Average loss: 3.2950
# Iteration: 604; Percent complete: 15.1%; Average loss: 3.3044
# Iteration: 605; Percent complete: 15.1%; Average loss: 3.4965
# Iteration: 606; Percent complete: 15.2%; Average loss: 3.3744
# Iteration: 607; Percent complete: 15.2%; Average loss: 4.6842
# Iteration: 608; Percent complete: 15.2%; Average loss: 3.6096
# Iteration: 609; Percent complete: 15.2%; Average loss: 4.0006
# Iteration: 610; Percent complete: 15.2%; Average loss: 4.1887
# Iteration: 611; Percent complete: 15.3%; Average loss: 3.3706
# Iteration: 612; Percent complete: 15.3%; Average loss: 3.7424
# Iteration: 613; Percent complete: 15.3%; Average loss: 3.7621
# Iteration: 614; Percent complete: 15.3%; Average loss: 4.0935
# Iteration: 615; Percent complete: 15.4%; Average loss: 3.4020
# Iteration: 616; Percent complete: 15.4%; Average loss: 3.1141
# Iteration: 617; Percent complete: 15.4%; Average loss: 3.4500
# Iteration: 618; Percent complete: 15.4%; Average loss: 3.3940
# Iteration: 619; Percent complete: 15.5%; Average loss: 3.8950
# Iteration: 620; Percent complete: 15.5%; Average loss: 4.0027
# Iteration: 621; Percent complete: 15.5%; Average loss: 3.3136
# Iteration: 622; Percent complete: 15.6%; Average loss: 3.2370
# Iteration: 623; Percent complete: 15.6%; Average loss: 4.3099
# Iteration: 624; Percent complete: 15.6%; Average loss: 3.4517
# Iteration: 625; Percent complete: 15.6%; Average loss: 3.1836
# Iteration: 626; Percent complete: 15.7%; Average loss: 3.6835
# Iteration: 627; Percent complete: 15.7%; Average loss: 3.8061
# Iteration: 628; Percent complete: 15.7%; Average loss: 3.1590
# Iteration: 629; Percent complete: 15.7%; Average loss: 4.4572
# Iteration: 630; Percent complete: 15.8%; Average loss: 3.5483
# Iteration: 631; Percent complete: 15.8%; Average loss: 3.3408
# Iteration: 632; Percent complete: 15.8%; Average loss: 3.7074
# Iteration: 633; Percent complete: 15.8%; Average loss: 3.7669
# Iteration: 634; Percent complete: 15.8%; Average loss: 3.1175
# Iteration: 635; Percent complete: 15.9%; Average loss: 3.6979
# Iteration: 636; Percent complete: 15.9%; Average loss: 4.0254
# Iteration: 637; Percent complete: 15.9%; Average loss: 2.7670
# Iteration: 638; Percent complete: 16.0%; Average loss: 3.4372
# Iteration: 639; Percent complete: 16.0%; Average loss: 3.8917
# Iteration: 640; Percent complete: 16.0%; Average loss: 3.6030
# Iteration: 641; Percent complete: 16.0%; Average loss: 3.2704
# Iteration: 642; Percent complete: 16.1%; Average loss: 3.7729
# Iteration: 643; Percent complete: 16.1%; Average loss: 3.4411
# Iteration: 644; Percent complete: 16.1%; Average loss: 3.5276
# Iteration: 645; Percent complete: 16.1%; Average loss: 2.5658
# Iteration: 646; Percent complete: 16.2%; Average loss: 3.5601
# Iteration: 647; Percent complete: 16.2%; Average loss: 4.2340
# Iteration: 648; Percent complete: 16.2%; Average loss: 4.5107
# Iteration: 649; Percent complete: 16.2%; Average loss: 3.3451
# Iteration: 650; Percent complete: 16.2%; Average loss: 4.1394
# Iteration: 651; Percent complete: 16.3%; Average loss: 3.6326
# Iteration: 652; Percent complete: 16.3%; Average loss: 3.9023
# Iteration: 653; Percent complete: 16.3%; Average loss: 3.3026
# Iteration: 654; Percent complete: 16.4%; Average loss: 4.0333
# Iteration: 655; Percent complete: 16.4%; Average loss: 3.5540
# Iteration: 656; Percent complete: 16.4%; Average loss: 3.2046
# Iteration: 657; Percent complete: 16.4%; Average loss: 4.2036
# Iteration: 658; Percent complete: 16.4%; Average loss: 3.1593
# Iteration: 659; Percent complete: 16.5%; Average loss: 3.0930
# Iteration: 660; Percent complete: 16.5%; Average loss: 3.5680
# Iteration: 661; Percent complete: 16.5%; Average loss: 4.0121
# Iteration: 662; Percent complete: 16.6%; Average loss: 4.2449
# Iteration: 663; Percent complete: 16.6%; Average loss: 2.9164
# Iteration: 664; Percent complete: 16.6%; Average loss: 3.2359
# Iteration: 665; Percent complete: 16.6%; Average loss: 3.0908
# Iteration: 666; Percent complete: 16.7%; Average loss: 2.5693
# Iteration: 667; Percent complete: 16.7%; Average loss: 3.0330
# Iteration: 668; Percent complete: 16.7%; Average loss: 3.6226
# Iteration: 669; Percent complete: 16.7%; Average loss: 3.9216
# Iteration: 670; Percent complete: 16.8%; Average loss: 3.3494
# Iteration: 671; Percent complete: 16.8%; Average loss: 3.6207
# Iteration: 672; Percent complete: 16.8%; Average loss: 3.2022
# Iteration: 673; Percent complete: 16.8%; Average loss: 2.6816
# Iteration: 674; Percent complete: 16.9%; Average loss: 3.5701
# Iteration: 675; Percent complete: 16.9%; Average loss: 4.2865
# Iteration: 676; Percent complete: 16.9%; Average loss: 4.1080
# Iteration: 677; Percent complete: 16.9%; Average loss: 4.1571
# Iteration: 678; Percent complete: 17.0%; Average loss: 3.4178
# Iteration: 679; Percent complete: 17.0%; Average loss: 3.0782
# Iteration: 680; Percent complete: 17.0%; Average loss: 3.8092
# Iteration: 681; Percent complete: 17.0%; Average loss: 3.7790
# Iteration: 682; Percent complete: 17.1%; Average loss: 3.7864
# Iteration: 683; Percent complete: 17.1%; Average loss: 3.9288
# Iteration: 684; Percent complete: 17.1%; Average loss: 3.6636
# Iteration: 685; Percent complete: 17.1%; Average loss: 3.2181
# Iteration: 686; Percent complete: 17.2%; Average loss: 3.2438
# Iteration: 687; Percent complete: 17.2%; Average loss: 4.4883
# Iteration: 688; Percent complete: 17.2%; Average loss: 3.6850
# Iteration: 689; Percent complete: 17.2%; Average loss: 3.7131
# Iteration: 690; Percent complete: 17.2%; Average loss: 2.8493
# Iteration: 691; Percent complete: 17.3%; Average loss: 3.8404
# Iteration: 692; Percent complete: 17.3%; Average loss: 3.8075
# Iteration: 693; Percent complete: 17.3%; Average loss: 3.5264
# Iteration: 694; Percent complete: 17.3%; Average loss: 3.2257
# Iteration: 695; Percent complete: 17.4%; Average loss: 3.8977
# Iteration: 696; Percent complete: 17.4%; Average loss: 3.8278
# Iteration: 697; Percent complete: 17.4%; Average loss: 3.4720
# Iteration: 698; Percent complete: 17.4%; Average loss: 3.4793
# Iteration: 699; Percent complete: 17.5%; Average loss: 3.6723
# Iteration: 700; Percent complete: 17.5%; Average loss: 3.3858
# Iteration: 701; Percent complete: 17.5%; Average loss: 3.4230
# Iteration: 702; Percent complete: 17.5%; Average loss: 3.4585
# Iteration: 703; Percent complete: 17.6%; Average loss: 3.9211
# Iteration: 704; Percent complete: 17.6%; Average loss: 3.8913
# Iteration: 705; Percent complete: 17.6%; Average loss: 3.4351
# Iteration: 706; Percent complete: 17.6%; Average loss: 3.6936
# Iteration: 707; Percent complete: 17.7%; Average loss: 3.6260
# Iteration: 708; Percent complete: 17.7%; Average loss: 3.5069
# Iteration: 709; Percent complete: 17.7%; Average loss: 3.2635
# Iteration: 710; Percent complete: 17.8%; Average loss: 3.6721
# Iteration: 711; Percent complete: 17.8%; Average loss: 3.8154
# Iteration: 712; Percent complete: 17.8%; Average loss: 3.1251
# Iteration: 713; Percent complete: 17.8%; Average loss: 3.8260
# Iteration: 714; Percent complete: 17.8%; Average loss: 3.8615
# Iteration: 715; Percent complete: 17.9%; Average loss: 3.6731
# Iteration: 716; Percent complete: 17.9%; Average loss: 3.0492
# Iteration: 717; Percent complete: 17.9%; Average loss: 3.6473
# Iteration: 718; Percent complete: 17.9%; Average loss: 4.0481
# Iteration: 719; Percent complete: 18.0%; Average loss: 3.7084
# Iteration: 720; Percent complete: 18.0%; Average loss: 3.3909
# Iteration: 721; Percent complete: 18.0%; Average loss: 3.9012
# Iteration: 722; Percent complete: 18.1%; Average loss: 3.4661
# Iteration: 723; Percent complete: 18.1%; Average loss: 2.6830
# Iteration: 724; Percent complete: 18.1%; Average loss: 3.5689
# Iteration: 725; Percent complete: 18.1%; Average loss: 3.7187
# Iteration: 726; Percent complete: 18.1%; Average loss: 3.9107
# Iteration: 727; Percent complete: 18.2%; Average loss: 3.7236
# Iteration: 728; Percent complete: 18.2%; Average loss: 3.6104
# Iteration: 729; Percent complete: 18.2%; Average loss: 3.3835
# Iteration: 730; Percent complete: 18.2%; Average loss: 2.9628
# Iteration: 731; Percent complete: 18.3%; Average loss: 3.5863
# Iteration: 732; Percent complete: 18.3%; Average loss: 3.1459
# Iteration: 733; Percent complete: 18.3%; Average loss: 3.9894
# Iteration: 734; Percent complete: 18.4%; Average loss: 3.4477
# Iteration: 735; Percent complete: 18.4%; Average loss: 3.3233
# Iteration: 736; Percent complete: 18.4%; Average loss: 4.4069
# Iteration: 737; Percent complete: 18.4%; Average loss: 3.7499
# Iteration: 738; Percent complete: 18.4%; Average loss: 3.8933
# Iteration: 739; Percent complete: 18.5%; Average loss: 3.6916
# Iteration: 740; Percent complete: 18.5%; Average loss: 3.1363
# Iteration: 741; Percent complete: 18.5%; Average loss: 2.7763
# Iteration: 742; Percent complete: 18.6%; Average loss: 3.4866
# Iteration: 743; Percent complete: 18.6%; Average loss: 3.2640
# Iteration: 744; Percent complete: 18.6%; Average loss: 3.7964
# Iteration: 745; Percent complete: 18.6%; Average loss: 3.3915
# Iteration: 746; Percent complete: 18.6%; Average loss: 4.1457
# Iteration: 747; Percent complete: 18.7%; Average loss: 3.2058
# Iteration: 748; Percent complete: 18.7%; Average loss: 3.4674
# Iteration: 749; Percent complete: 18.7%; Average loss: 3.2389
# Iteration: 750; Percent complete: 18.8%; Average loss: 3.8662
# Iteration: 751; Percent complete: 18.8%; Average loss: 3.7694
# Iteration: 752; Percent complete: 18.8%; Average loss: 3.3011
# Iteration: 753; Percent complete: 18.8%; Average loss: 3.6119
# Iteration: 754; Percent complete: 18.9%; Average loss: 3.2175
# Iteration: 755; Percent complete: 18.9%; Average loss: 3.2403
# Iteration: 756; Percent complete: 18.9%; Average loss: 3.4411
# Iteration: 757; Percent complete: 18.9%; Average loss: 3.8189
# Iteration: 758; Percent complete: 18.9%; Average loss: 3.2267
# Iteration: 759; Percent complete: 19.0%; Average loss: 3.5100
# Iteration: 760; Percent complete: 19.0%; Average loss: 4.1891
# Iteration: 761; Percent complete: 19.0%; Average loss: 3.6652
# Iteration: 762; Percent complete: 19.1%; Average loss: 3.3619
# Iteration: 763; Percent complete: 19.1%; Average loss: 3.3797
# Iteration: 764; Percent complete: 19.1%; Average loss: 4.1244
# Iteration: 765; Percent complete: 19.1%; Average loss: 2.4470
# Iteration: 766; Percent complete: 19.1%; Average loss: 3.6413
# Iteration: 767; Percent complete: 19.2%; Average loss: 3.5979
# Iteration: 768; Percent complete: 19.2%; Average loss: 3.1256
# Iteration: 769; Percent complete: 19.2%; Average loss: 2.7324
# Iteration: 770; Percent complete: 19.2%; Average loss: 3.3644
# Iteration: 771; Percent complete: 19.3%; Average loss: 2.9035
# Iteration: 772; Percent complete: 19.3%; Average loss: 3.4809
# Iteration: 773; Percent complete: 19.3%; Average loss: 3.4468
# Iteration: 774; Percent complete: 19.4%; Average loss: 2.5647
# Iteration: 775; Percent complete: 19.4%; Average loss: 2.8818
# Iteration: 776; Percent complete: 19.4%; Average loss: 3.7487
# Iteration: 777; Percent complete: 19.4%; Average loss: 3.6400
# Iteration: 778; Percent complete: 19.4%; Average loss: 3.9412
# Iteration: 779; Percent complete: 19.5%; Average loss: 2.9838
# Iteration: 780; Percent complete: 19.5%; Average loss: 3.5302
# Iteration: 781; Percent complete: 19.5%; Average loss: 3.3392
# ...
# Iteration: 2308; Percent complete: 57.7%; Average loss: 2.4710
# Iteration: 2309; Percent complete: 57.7%; Average loss: 2.5182
# Iteration: 2310; Percent complete: 57.8%; Average loss: 2.1208
# Iteration: 2311; Percent complete: 57.8%; Average loss: 2.5303
# Iteration: 2312; Percent complete: 57.8%; Average loss: 2.1109
# Iteration: 2313; Percent complete: 57.8%; Average loss: 2.8037
# Iteration: 2314; Percent complete: 57.9%; Average loss: 2.3265
# Iteration: 2315; Percent complete: 57.9%; Average loss: 2.6843
# Iteration: 2316; Percent complete: 57.9%; Average loss: 2.7141
# Iteration: 2317; Percent complete: 57.9%; Average loss: 2.6814
# Iteration: 2318; Percent complete: 58.0%; Average loss: 1.8120
# Iteration: 2319; Percent complete: 58.0%; Average loss: 2.3780
# Iteration: 2320; Percent complete: 58.0%; Average loss: 2.4882
# Iteration: 2321; Percent complete: 58.0%; Average loss: 2.1949
# Iteration: 2322; Percent complete: 58.1%; Average loss: 2.4407
# Iteration: 2323; Percent complete: 58.1%; Average loss: 2.6063
# Iteration: 2324; Percent complete: 58.1%; Average loss: 2.0638
# Iteration: 2325; Percent complete: 58.1%; Average loss: 2.3024
# Iteration: 2326; Percent complete: 58.1%; Average loss: 2.5536
# Iteration: 2327; Percent complete: 58.2%; Average loss: 2.9026
# Iteration: 2328; Percent complete: 58.2%; Average loss: 2.6118
# Iteration: 2329; Percent complete: 58.2%; Average loss: 2.4546
# Iteration: 2330; Percent complete: 58.2%; Average loss: 2.0174
# Iteration: 2331; Percent complete: 58.3%; Average loss: 2.2177
# Iteration: 2332; Percent complete: 58.3%; Average loss: 2.5787
# Iteration: 2333; Percent complete: 58.3%; Average loss: 2.5820
# Iteration: 2334; Percent complete: 58.4%; Average loss: 3.2865
# Iteration: 2335; Percent complete: 58.4%; Average loss: 2.3010
# Iteration: 2336; Percent complete: 58.4%; Average loss: 2.6439
# Iteration: 2337; Percent complete: 58.4%; Average loss: 2.3755
# Iteration: 2338; Percent complete: 58.5%; Average loss: 2.1469
# Iteration: 2339; Percent complete: 58.5%; Average loss: 2.9051
# Iteration: 2340; Percent complete: 58.5%; Average loss: 2.4498
# Iteration: 2341; Percent complete: 58.5%; Average loss: 2.4445
# Iteration: 2342; Percent complete: 58.6%; Average loss: 2.4207
# Iteration: 2343; Percent complete: 58.6%; Average loss: 2.5937
# Iteration: 2344; Percent complete: 58.6%; Average loss: 2.5930
# Iteration: 2345; Percent complete: 58.6%; Average loss: 2.6439
# Iteration: 2346; Percent complete: 58.7%; Average loss: 2.6261
# Iteration: 2347; Percent complete: 58.7%; Average loss: 2.2296
# Iteration: 2348; Percent complete: 58.7%; Average loss: 2.6818
# Iteration: 2349; Percent complete: 58.7%; Average loss: 3.0505
# Iteration: 2350; Percent complete: 58.8%; Average loss: 2.2308
# Iteration: 2351; Percent complete: 58.8%; Average loss: 2.7093
# Iteration: 2352; Percent complete: 58.8%; Average loss: 2.7534
# Iteration: 2353; Percent complete: 58.8%; Average loss: 2.8764
# Iteration: 2354; Percent complete: 58.9%; Average loss: 2.1137
# Iteration: 2355; Percent complete: 58.9%; Average loss: 2.5411
# Iteration: 2356; Percent complete: 58.9%; Average loss: 2.5747
# Iteration: 2357; Percent complete: 58.9%; Average loss: 2.8784
# Iteration: 2358; Percent complete: 59.0%; Average loss: 2.8512
# Iteration: 2359; Percent complete: 59.0%; Average loss: 2.8559
# Iteration: 2360; Percent complete: 59.0%; Average loss: 2.9757
# Iteration: 2361; Percent complete: 59.0%; Average loss: 2.5614
# Iteration: 2362; Percent complete: 59.1%; Average loss: 2.7177
# Iteration: 2363; Percent complete: 59.1%; Average loss: 2.3779
# Iteration: 2364; Percent complete: 59.1%; Average loss: 2.5594
# Iteration: 2365; Percent complete: 59.1%; Average loss: 2.5754
# Iteration: 2366; Percent complete: 59.2%; Average loss: 2.9956
# Iteration: 2367; Percent complete: 59.2%; Average loss: 2.3754
# Iteration: 2368; Percent complete: 59.2%; Average loss: 2.4342
# Iteration: 2369; Percent complete: 59.2%; Average loss: 2.6348
# Iteration: 2370; Percent complete: 59.2%; Average loss: 2.6102
# Iteration: 2371; Percent complete: 59.3%; Average loss: 2.3068
# Iteration: 2372; Percent complete: 59.3%; Average loss: 2.6989
# Iteration: 2373; Percent complete: 59.3%; Average loss: 2.4616
# Iteration: 2374; Percent complete: 59.4%; Average loss: 2.7071
# Iteration: 2375; Percent complete: 59.4%; Average loss: 2.0489
# Iteration: 2376; Percent complete: 59.4%; Average loss: 2.3413
# Iteration: 2377; Percent complete: 59.4%; Average loss: 2.8672
# Iteration: 2378; Percent complete: 59.5%; Average loss: 2.2047
# Iteration: 2379; Percent complete: 59.5%; Average loss: 2.2131
# Iteration: 2380; Percent complete: 59.5%; Average loss: 2.6495
# Iteration: 2381; Percent complete: 59.5%; Average loss: 2.9945
# Iteration: 2382; Percent complete: 59.6%; Average loss: 3.0768
# Iteration: 2383; Percent complete: 59.6%; Average loss: 2.8221
# Iteration: 2384; Percent complete: 59.6%; Average loss: 2.6451
# Iteration: 2385; Percent complete: 59.6%; Average loss: 2.1242
# Iteration: 2386; Percent complete: 59.7%; Average loss: 2.5085
# Iteration: 2387; Percent complete: 59.7%; Average loss: 2.0129
# Iteration: 2388; Percent complete: 59.7%; Average loss: 2.5560
# Iteration: 2389; Percent complete: 59.7%; Average loss: 2.4633
# Iteration: 2390; Percent complete: 59.8%; Average loss: 3.0066
# Iteration: 2391; Percent complete: 59.8%; Average loss: 2.5764
# Iteration: 2392; Percent complete: 59.8%; Average loss: 2.2405
# Iteration: 2393; Percent complete: 59.8%; Average loss: 2.9536
# Iteration: 2394; Percent complete: 59.9%; Average loss: 2.0258
# Iteration: 2395; Percent complete: 59.9%; Average loss: 2.3973
# Iteration: 2396; Percent complete: 59.9%; Average loss: 2.0984
# Iteration: 2397; Percent complete: 59.9%; Average loss: 2.4353
# Iteration: 2398; Percent complete: 60.0%; Average loss: 2.8029
# Iteration: 2399; Percent complete: 60.0%; Average loss: 2.0261
# Iteration: 2400; Percent complete: 60.0%; Average loss: 2.5078
# Iteration: 2401; Percent complete: 60.0%; Average loss: 3.0139
# Iteration: 2402; Percent complete: 60.1%; Average loss: 2.4099
# Iteration: 2403; Percent complete: 60.1%; Average loss: 2.5630
# Iteration: 2404; Percent complete: 60.1%; Average loss: 2.2171
# Iteration: 2405; Percent complete: 60.1%; Average loss: 2.4096
# Iteration: 2406; Percent complete: 60.2%; Average loss: 2.7186
# Iteration: 2407; Percent complete: 60.2%; Average loss: 2.1794
# Iteration: 2408; Percent complete: 60.2%; Average loss: 2.5516
# Iteration: 2409; Percent complete: 60.2%; Average loss: 2.4586
# Iteration: 2410; Percent complete: 60.2%; Average loss: 2.3127
# Iteration: 2411; Percent complete: 60.3%; Average loss: 2.5638
# Iteration: 2412; Percent complete: 60.3%; Average loss: 2.4681
# Iteration: 2413; Percent complete: 60.3%; Average loss: 3.0380
# Iteration: 2414; Percent complete: 60.4%; Average loss: 1.9043
# Iteration: 2415; Percent complete: 60.4%; Average loss: 2.6497
# Iteration: 2416; Percent complete: 60.4%; Average loss: 2.3922
# Iteration: 2417; Percent complete: 60.4%; Average loss: 2.0545
# Iteration: 2418; Percent complete: 60.5%; Average loss: 2.6623
# Iteration: 2419; Percent complete: 60.5%; Average loss: 2.3841
# Iteration: 2420; Percent complete: 60.5%; Average loss: 2.3325
# Iteration: 2421; Percent complete: 60.5%; Average loss: 2.6297
# Iteration: 2422; Percent complete: 60.6%; Average loss: 2.1719
# Iteration: 2423; Percent complete: 60.6%; Average loss: 2.3912
# Iteration: 2424; Percent complete: 60.6%; Average loss: 2.3889
# Iteration: 2425; Percent complete: 60.6%; Average loss: 2.5967
# Iteration: 2426; Percent complete: 60.7%; Average loss: 2.7106
# Iteration: 2427; Percent complete: 60.7%; Average loss: 2.5566
# Iteration: 2428; Percent complete: 60.7%; Average loss: 2.0738
# Iteration: 2429; Percent complete: 60.7%; Average loss: 2.4064
# Iteration: 2430; Percent complete: 60.8%; Average loss: 2.8074
# Iteration: 2431; Percent complete: 60.8%; Average loss: 1.9269
# Iteration: 2432; Percent complete: 60.8%; Average loss: 1.8565
# Iteration: 2433; Percent complete: 60.8%; Average loss: 1.9511
# Iteration: 2434; Percent complete: 60.9%; Average loss: 2.9150
# Iteration: 2435; Percent complete: 60.9%; Average loss: 1.7574
# Iteration: 2436; Percent complete: 60.9%; Average loss: 2.6294
# Iteration: 2437; Percent complete: 60.9%; Average loss: 2.7842
# Iteration: 2438; Percent complete: 61.0%; Average loss: 2.6461
# Iteration: 2439; Percent complete: 61.0%; Average loss: 2.5159
# Iteration: 2440; Percent complete: 61.0%; Average loss: 2.9042
# Iteration: 2441; Percent complete: 61.0%; Average loss: 1.8163
# Iteration: 2442; Percent complete: 61.1%; Average loss: 2.8398
# Iteration: 2443; Percent complete: 61.1%; Average loss: 2.3587
# Iteration: 2444; Percent complete: 61.1%; Average loss: 2.1456
# Iteration: 2445; Percent complete: 61.1%; Average loss: 2.7967
# Iteration: 2446; Percent complete: 61.2%; Average loss: 2.2921
# Iteration: 2447; Percent complete: 61.2%; Average loss: 2.7329
# Iteration: 2448; Percent complete: 61.2%; Average loss: 2.6939
# Iteration: 2449; Percent complete: 61.2%; Average loss: 2.0132
# Iteration: 2450; Percent complete: 61.3%; Average loss: 2.4344
# Iteration: 2451; Percent complete: 61.3%; Average loss: 1.8552
# Iteration: 2452; Percent complete: 61.3%; Average loss: 2.2805
# Iteration: 2453; Percent complete: 61.3%; Average loss: 1.9948
# Iteration: 2454; Percent complete: 61.4%; Average loss: 1.9524
# Iteration: 2455; Percent complete: 61.4%; Average loss: 2.6471
# Iteration: 2456; Percent complete: 61.4%; Average loss: 2.5341
# Iteration: 2457; Percent complete: 61.4%; Average loss: 2.4899
# Iteration: 2458; Percent complete: 61.5%; Average loss: 2.4925
# Iteration: 2459; Percent complete: 61.5%; Average loss: 2.1710
# Iteration: 2460; Percent complete: 61.5%; Average loss: 2.6353
# Iteration: 2461; Percent complete: 61.5%; Average loss: 2.8844
# Iteration: 2462; Percent complete: 61.6%; Average loss: 2.3783
# Iteration: 2463; Percent complete: 61.6%; Average loss: 2.1438
# Iteration: 2464; Percent complete: 61.6%; Average loss: 2.2885
# Iteration: 2465; Percent complete: 61.6%; Average loss: 2.6164
# Iteration: 2466; Percent complete: 61.7%; Average loss: 2.1897
# Iteration: 2467; Percent complete: 61.7%; Average loss: 2.4741
# Iteration: 2468; Percent complete: 61.7%; Average loss: 2.3243
# Iteration: 2469; Percent complete: 61.7%; Average loss: 2.5607
# Iteration: 2470; Percent complete: 61.8%; Average loss: 2.5501
# Iteration: 2471; Percent complete: 61.8%; Average loss: 2.4709
# Iteration: 2472; Percent complete: 61.8%; Average loss: 2.2718
# Iteration: 2473; Percent complete: 61.8%; Average loss: 2.6287
# Iteration: 2474; Percent complete: 61.9%; Average loss: 2.4691
# Iteration: 2475; Percent complete: 61.9%; Average loss: 2.3464
# Iteration: 2476; Percent complete: 61.9%; Average loss: 2.1371
# Iteration: 2477; Percent complete: 61.9%; Average loss: 2.1379
# Iteration: 2478; Percent complete: 62.0%; Average loss: 2.3814
# Iteration: 2479; Percent complete: 62.0%; Average loss: 2.4292
# Iteration: 2480; Percent complete: 62.0%; Average loss: 2.6560
# Iteration: 2481; Percent complete: 62.0%; Average loss: 2.3493
# Iteration: 2482; Percent complete: 62.1%; Average loss: 1.9774
# Iteration: 2483; Percent complete: 62.1%; Average loss: 1.9365
# Iteration: 2484; Percent complete: 62.1%; Average loss: 2.6264
# Iteration: 2485; Percent complete: 62.1%; Average loss: 2.2972
# Iteration: 2486; Percent complete: 62.2%; Average loss: 2.4154
# Iteration: 2487; Percent complete: 62.2%; Average loss: 2.2636
# Iteration: 2488; Percent complete: 62.2%; Average loss: 2.3526
# Iteration: 2489; Percent complete: 62.2%; Average loss: 2.4055
# Iteration: 2490; Percent complete: 62.3%; Average loss: 2.7133
# Iteration: 2491; Percent complete: 62.3%; Average loss: 2.2068
# Iteration: 2492; Percent complete: 62.3%; Average loss: 2.3550
# Iteration: 2493; Percent complete: 62.3%; Average loss: 2.4679
# Iteration: 2494; Percent complete: 62.4%; Average loss: 2.4254
# Iteration: 2495; Percent complete: 62.4%; Average loss: 2.3430
# Iteration: 2496; Percent complete: 62.4%; Average loss: 2.3459
# Iteration: 2497; Percent complete: 62.4%; Average loss: 2.0056
# Iteration: 2498; Percent complete: 62.5%; Average loss: 2.7572
# Iteration: 2499; Percent complete: 62.5%; Average loss: 1.9220
# Iteration: 2500; Percent complete: 62.5%; Average loss: 2.7983
# Iteration: 2501; Percent complete: 62.5%; Average loss: 2.2405
# Iteration: 2502; Percent complete: 62.5%; Average loss: 2.4497
# Iteration: 2503; Percent complete: 62.6%; Average loss: 2.6381
# Iteration: 2504; Percent complete: 62.6%; Average loss: 2.3588
# Iteration: 2505; Percent complete: 62.6%; Average loss: 1.7903
# Iteration: 2506; Percent complete: 62.6%; Average loss: 2.3395
# Iteration: 2507; Percent complete: 62.7%; Average loss: 2.3599
# Iteration: 2508; Percent complete: 62.7%; Average loss: 2.4556
# Iteration: 2509; Percent complete: 62.7%; Average loss: 2.8325
# Iteration: 2510; Percent complete: 62.7%; Average loss: 2.4635
# Iteration: 2511; Percent complete: 62.8%; Average loss: 1.7330
# Iteration: 2512; Percent complete: 62.8%; Average loss: 2.3120
# Iteration: 2513; Percent complete: 62.8%; Average loss: 2.8798
# Iteration: 2514; Percent complete: 62.8%; Average loss: 2.4305
# Iteration: 2515; Percent complete: 62.9%; Average loss: 2.2605
# Iteration: 2516; Percent complete: 62.9%; Average loss: 2.4286
# Iteration: 2517; Percent complete: 62.9%; Average loss: 2.5858
# Iteration: 2518; Percent complete: 62.9%; Average loss: 2.4398
# Iteration: 2519; Percent complete: 63.0%; Average loss: 2.4745
# Iteration: 2520; Percent complete: 63.0%; Average loss: 2.3234
# Iteration: 2521; Percent complete: 63.0%; Average loss: 3.0534
# Iteration: 2522; Percent complete: 63.0%; Average loss: 2.6525
# Iteration: 2523; Percent complete: 63.1%; Average loss: 2.4040
# Iteration: 2524; Percent complete: 63.1%; Average loss: 2.4283
# Iteration: 2525; Percent complete: 63.1%; Average loss: 2.0832
# Iteration: 2526; Percent complete: 63.1%; Average loss: 2.3066
# Iteration: 2527; Percent complete: 63.2%; Average loss: 2.3846
# Iteration: 2528; Percent complete: 63.2%; Average loss: 2.2727
# Iteration: 2529; Percent complete: 63.2%; Average loss: 2.4581
# Iteration: 2530; Percent complete: 63.2%; Average loss: 2.5766
# Iteration: 2531; Percent complete: 63.3%; Average loss: 2.3463
# Iteration: 2532; Percent complete: 63.3%; Average loss: 2.0862
# Iteration: 2533; Percent complete: 63.3%; Average loss: 2.4196
# Iteration: 2534; Percent complete: 63.3%; Average loss: 2.7814
# Iteration: 2535; Percent complete: 63.4%; Average loss: 2.0351
# Iteration: 2536; Percent complete: 63.4%; Average loss: 2.8586
# Iteration: 2537; Percent complete: 63.4%; Average loss: 2.6366
# Iteration: 2538; Percent complete: 63.4%; Average loss: 2.0648
# Iteration: 2539; Percent complete: 63.5%; Average loss: 2.3847
# Iteration: 2540; Percent complete: 63.5%; Average loss: 2.8870
# Iteration: 2541; Percent complete: 63.5%; Average loss: 2.7989
# Iteration: 2542; Percent complete: 63.5%; Average loss: 2.6292
# Iteration: 2543; Percent complete: 63.6%; Average loss: 2.6348
# Iteration: 2544; Percent complete: 63.6%; Average loss: 2.4710
# Iteration: 2545; Percent complete: 63.6%; Average loss: 2.4916
# Iteration: 2546; Percent complete: 63.6%; Average loss: 2.5614
# Iteration: 2547; Percent complete: 63.7%; Average loss: 2.4637
# Iteration: 2548; Percent complete: 63.7%; Average loss: 2.3690
# Iteration: 2549; Percent complete: 63.7%; Average loss: 2.4029
# Iteration: 2550; Percent complete: 63.7%; Average loss: 2.0704
# Iteration: 2551; Percent complete: 63.8%; Average loss: 2.3403
# Iteration: 2552; Percent complete: 63.8%; Average loss: 2.4547
# Iteration: 2553; Percent complete: 63.8%; Average loss: 2.8106
# Iteration: 2554; Percent complete: 63.8%; Average loss: 1.7236
# Iteration: 2555; Percent complete: 63.9%; Average loss: 2.5121
# Iteration: 2556; Percent complete: 63.9%; Average loss: 1.8556
# Iteration: 2557; Percent complete: 63.9%; Average loss: 2.7007
# Iteration: 2558; Percent complete: 63.9%; Average loss: 2.3953
# Iteration: 2559; Percent complete: 64.0%; Average loss: 1.8142
# Iteration: 2560; Percent complete: 64.0%; Average loss: 2.0920

# %% [markdown]
# Run Evaluation
# ~~~~~~~~~~~~~~
#
# To chat with your model, run the following block.

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# Bot: hi . . . . .
# Bot: i m fine . . . !
# Bot: fine . you re not . ?
# Bot: yes . . . ? ?
# Bot: i don t know . . .
# Error: Encountered unknown word.
# Bot: you re a cop . ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: you re not . ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# Bot: what ? ? ? ? ?
# KeyboardInterrupt

# %% [markdown]
# Conclusion
# ----------
#
# That’s all for this one, folks. Congratulations, you now know the
# fundamentals to building a generative chatbot model! If you’re
# interested, you can try tailoring the chatbot’s behavior by tweaking the
# model and training parameters and customizing the data that you train
# the model on.
#
# Check out the other tutorials for more cool deep learning applications
# in PyTorch!
